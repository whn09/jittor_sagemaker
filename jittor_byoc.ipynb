# %% [markdown]
# # Building your own TensorFlow container
#
# With Amazon SageMaker, you can package your own algorithms that can then be trained and deployed in the SageMaker environment. This notebook guides you through an example using TensorFlow that shows you how to build a Docker container for SageMaker and use it for training and inference.
#
# By packaging an algorithm in a container, you can bring almost any code to the Amazon SageMaker environment, regardless of programming language, environment, framework, or dependencies.
#
# 1. [Building your own TensorFlow container](#Building-your-own-tensorflow-container)
#   1. [When should I build my own algorithm container?](#When-should-I-build-my-own-algorithm-container?)
#   1. [Permissions](#Permissions)
#   1. [The example](#The-example)
#   1. [The presentation](#The-presentation)
# 1. [Part 1: Packaging and Uploading your Algorithm for use with Amazon SageMaker](#Part-1:-Packaging-and-Uploading-your-Algorithm-for-use-with-Amazon-SageMaker)
#     1. [An overview of Docker](#An-overview-of-Docker)
#     1. [How Amazon SageMaker runs your Docker container](#How-Amazon-SageMaker-runs-your-Docker-container)
#       1. [Running your container during training](#Running-your-container-during-training)
#         1. [The input](#The-input)
#         1. [The output](#The-output)
#       1. [Running your container during hosting](#Running-your-container-during-hosting)
#     1. [The parts of the sample container](#The-parts-of-the-sample-container)
#     1. [The Dockerfile](#The-Dockerfile)
#     1. [Building and registering the container](#Building-and-registering-the-container)
#   1. [Testing your algorithm on your local machine](#Testing-your-algorithm-on-your-local-machine)
# 1. [Part 2: Training and Hosting your Algorithm in Amazon SageMaker](#Part-2:-Training-and-Hosting-your-Algorithm-in-Amazon-SageMaker)
#   1. [Set up the environment](#Set-up-the-environment)
#   1. [Create the session](#Create-the-session)
#   1. [Upload the data for training](#Upload-the-data-for-training)
#   1. [Training On SageMaker](#Training-on-SageMaker)
#   1. [Optional cleanup](#Optional-cleanup)
# 1. [Reference](#Reference)
#
# _or_ I'm impatient, just [let me see the code](#The-Dockerfile)!
#
# ## When should I build my own algorithm container?
#
# You may not need to create a container to bring your own code to Amazon SageMaker. When you are using a framework such as Apache MXNet or TensorFlow that has direct support in SageMaker, you can simply supply the Python code that implements your algorithm using the SDK entry points for that framework. This set of supported frameworks is regularly added to, so you should check the current list to determine whether your algorithm is written in one of these common machine learning environments.
#
# Even if there is direct SDK support for your environment or framework, you may find it more effective to build your own container. If the code that implements your algorithm is quite complex or you need special additions to the framework, building your own container may be the right choice.
#
# Some of the reasons to build an already supported framework container are:
# 1. A specific version isn't supported.
# 2. Configure and install your dependencies and environment.
# 3. Use a different training/hosting solution than provided.
#
# This walkthrough shows that it is quite straightforward to build your own container. So you can still use SageMaker even if your use case is not covered by the deep learning containers that we've built for you.
#
# ## Permissions
#
# Running this notebook requires permissions in addition to the normal `SageMakerFullAccess` permissions. This is because it creates new repositories in Amazon ECR. The easiest way to add these permissions is simply to add the managed policy `AmazonEC2ContainerRegistryFullAccess` to the role that you used to start your notebook instance. There's no need to restart your notebook instance when you do this, the new permissions will be available immediately.
#
# ## The example
#
# In this example we show how to package a custom TensorFlow container with a Python example which works with the CIFAR-10 dataset and uses TensorFlow Serving for inference. However, different inference solutions other than TensorFlow Serving can be used by modifying the docker container.
#
# In this example, we use a single image to support training and hosting. This simplifies the procedure because we only need to manage one image for both tasks. Sometimes you may want separate images for training and hosting because they have different requirements. In this case, separate the parts discussed below into separate Dockerfiles and build two images. Choosing whether to use a single image or two images is a matter of what is most convenient for you to develop and manage.
#
# If you're only using Amazon SageMaker for training or hosting, but not both, only the functionality used needs to be built into your container.
#
# [CIFAR-10]: http://www.cs.toronto.edu/~kriz/cifar.html
#
# ## The presentation
#
# This presentation is divided into two parts: _building_ the container and _using_ the container.

# %% [markdown]
# # Part 1: Packaging and Uploading your Algorithm for use with Amazon SageMaker
#
# ### An overview of Docker
#
# If you're familiar with Docker already, you can skip ahead to the next section.
#
# For many data scientists, Docker containers are a new technology. But they are not difficult and can significantly simply the deployment of your software packages.
#
# Docker provides a simple way to package arbitrary code into an _image_ that is totally self-contained. Once you have an image, you can use Docker to run a _container_ based on that image. Running a container is just like running a program on the machine except that the container creates a fully self-contained environment for the program to run. Containers are isolated from each other and from the host environment, so the way your program is set up is the way it runs, no matter where you run it.
#
# Docker is more powerful than environment managers like conda or virtualenv because (a) it is completely language independent and (b) it comprises your whole operating environment, including startup commands, and environment variable.
#
# A Docker container is like a virtual machine, but it is much lighter weight. For example, a program running in a container can start in less than a second and many containers can run simultaneously on the same physical or virtual machine instance.
#
# Docker uses a simple file called a `Dockerfile` to specify how the image is assembled. An example is provided below. You can build your Docker images based on Docker images built by yourself or by others, which can simplify things quite a bit.
#
# Docker has become very popular in programming and devops communities due to its flexibility and its well-defined specification of how code can be run in its containers. It is the underpinning of many services built in the past few years, such as [Amazon ECS].
#
# Amazon SageMaker uses Docker to allow users to train and deploy arbitrary algorithms.
#
# In Amazon SageMaker, Docker containers are invoked in a one way for training and another, slightly different, way for hosting. The following sections outline how to build containers for the SageMaker environment.
#
# Some helpful links:
#
# * [Docker home page](http://www.docker.com)
# * [Getting started with Docker](https://docs.docker.com/get-started/)
# * [Dockerfile reference](https://docs.docker.com/engine/reference/builder/)
# * [`docker run` reference](https://docs.docker.com/engine/reference/run/)
#
# [Amazon ECS]: https://aws.amazon.com/ecs/
#
# ### How Amazon SageMaker runs your Docker container
#
# Because you can run the same image in training or hosting, Amazon SageMaker runs your container with the argument `train` or `serve`. How your container processes this argument depends on the container.
#
# * In this example, we don't define an `ENTRYPOINT` in the Dockerfile so Docker runs the command [`train` at training time](https://docs.aws.amazon.com/sagemaker/latest/dg/your-algorithms-training-algo.html) and [`serve` at serving time](https://docs.aws.amazon.com/sagemaker/latest/dg/your-algorithms-inference-code.html). In this example, we define these as executable Python scripts, but they could be any program that we want to start in that environment.
# * If you specify a program as an `ENTRYPOINT` in the Dockerfile, that program will be run at startup and its first argument will be `train` or `serve`. The program can then look at that argument and decide what to do.
# * If you are building separate containers for training and hosting (or building only for one or the other), you can define a program as an `ENTRYPOINT` in the Dockerfile and ignore (or verify) the first argument passed in.
#
# #### Running your container during training
#
# When Amazon SageMaker runs training, your `train` script is run, as in a regular Python program. A number of files are laid out for your use, under the `/opt/ml` directory:
#
#     /opt/ml
#     |-- code
#     |   `-- <code files>
#     |-- input
#     |   |-- config
#     |   |   |-- hyperparameters.json
#     |   |   `-- resourceConfig.json
#     |   `-- data
#     |       `-- <channel_name>
#     |           `-- <input data>
#     |-- model
#     |   `-- <model files>
#     `-- output
#         `-- failure
#
# ##### The input
#
# * `/opt/ml/input/config` contains information to control how your program runs. `hyperparameters.json` is a JSON-formatted dictionary of hyperparameter names to values. These values are always strings, so you may need to convert them. `resourceConfig.json` is a JSON-formatted file that describes the network layout used for distributed training.
# * `/opt/ml/input/data/<channel_name>/` (for File mode) contains the input data for that channel. The channels are created based on the call to CreateTrainingJob but it's generally important that channels match algorithm expectations. The files for each channel are copied from S3 to this directory, preserving the tree structure indicated by the S3 key structure.
# * `/opt/ml/input/data/<channel_name>_<epoch_number>` (for Pipe mode) is the pipe for a given epoch. Epochs start at zero and go up by one each time you read them. There is no limit to the number of epochs that you can run, but you must close each pipe before reading the next epoch.
#
# ##### The output
#
# * `/opt/ml/model/` is the directory where you write the model that your algorithm generates. Your model can be in any format that you want. It can be a single file or a whole directory tree. SageMaker packages any files in this directory into a compressed tar archive file. This file is made available at the S3 location returned in the `DescribeTrainingJob` result.
# * `/opt/ml/output` is a directory where the algorithm can write a file `failure` that describes why the job failed. The contents of this file are returned in the `FailureReason` field of the `DescribeTrainingJob` result. For jobs that succeed, there is no reason to write this file as it is ignored.
#
# #### Running your container during hosting
#
# Hosting has a very different model than training because hosting is reponding to inference requests that come in via HTTP. In this example, we use [TensorFlow Serving](https://www.tensorflow.org/serving/), however the hosting solution can be customized. One example is the [Python serving stack within the scikit learn example](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/advanced_functionality/scikit_bring_your_own/scikit_bring_your_own.ipynb).
#
# Amazon SageMaker uses two URLs in the container:
#
# * `/ping` receives `GET` requests from the infrastructure. Your program returns 200 if the container is up and accepting requests.
# * `/invocations` is the endpoint that receives client inference `POST` requests. The format of the request and the response is up to the algorithm. If the client supplied `ContentType` and `Accept` headers, these are passed in as well.
#
# The container has the model files in the same place that they were written to during training:
#
#     /opt/ml
#     `-- model
#         `-- <model files>

# %% [markdown]
# ### The parts of the sample container
#
# The `container` directory has all the components you need to package the sample algorithm for Amazon SageMager:
#
#     .
#     |-- Dockerfile
#     |-- build_and_push.sh
#     `-- cifar10
#         |-- cifar10.py
#         |-- resnet_model.py
#         |-- nginx.conf
#         |-- serve
#         `-- train
#
# Let's discuss each of these in turn:
#
# * __`Dockerfile`__ describes how to build your Docker container image. More details are provided below.
# * __`build_and_push.sh`__ is a script that uses the Dockerfile to build your container images and then pushes it to ECR. We invoke the commands directly later in this notebook, but you can just copy and run the script for your own algorithms.
# * __`cifar10`__ is the directory which contains the files that are installed in the container.
#
# In this simple application, we install only five files in the container. You may only need that many, but if you have many supporting routines, you may wish to install more. These five files show the standard structure of our Python containers, although you are free to choose a different toolset and therefore could have a different layout. If you're writing in a different programming language, you will have a different layout depending on the frameworks and tools you choose.
#
# The files that we put in the container are:
#
# * __`cifar10.py`__ is the program that implements our training algorithm.
# * __`resnet_model.py`__ is the program that contains our Resnet model.
# * __`nginx.conf`__ is the configuration file for the nginx front-end. Generally, you should be able to take this file as-is.
# * __`serve`__ is the program started when the container is started for hosting. It simply launches nginx and loads your exported model with TensorFlow Serving.
# * __`train`__ is the program that is invoked when the container is run for training. Our implementation of this script invokes cifar10.py with our our hyperparameter values retrieved from /opt/ml/input/config/hyperparameters.json. The goal for doing this is to avoid having to modify our training algorithm program.
#
# In summary, the two files you probably want to change for your application are `train` and `serve`.

# %% [markdown]
# ### The Dockerfile
#
# The Dockerfile describes the image that we want to build. You can think of it as describing the complete operating system installation of the system that you want to run. A Docker container running is quite a bit lighter than a full operating system, however, because it takes advantage of Linux on the host machine for the basic operations.
#
# For the Python science stack, we start from an official TensorFlow docker image and run the normal tools to install TensorFlow Serving. Then we add the code that implements our specific algorithm to the container and set up the right environment for it to run under.
#
# Let's look at the Dockerfile for this example.

# %%
# !cat Dockerfile

# %% [markdown]
# ### Building and registering the container
#
# The following shell code shows how to build the container image using `docker build` and push the container image to ECR using `docker push`. This code is also available as the shell script `container/build-and-push.sh`, which you can run as `build-and-push.sh sagemaker-tf-cifar10-example` to build the image `sagemaker-tf-cifar10-example`.
#
# This code looks for an ECR repository in the account you're using and the current default region (if you're using a SageMaker notebook instance, this is the region where the notebook instance was created). If the repository doesn't exist, the script will create it.

# %%
# !build_and_push.sh jittor

# %% [markdown]
# ## Testing your algorithm on your local machine
#
# When you're packaging you first algorithm to use with Amazon SageMaker, you probably want to test it yourself to make sure it's working correctly. We use the [SageMaker Python SDK](https://github.com/aws/sagemaker-python-sdk) to test both locally and on SageMaker. For more examples with the SageMaker Python SDK, see [Amazon SageMaker Examples](https://github.com/awslabs/amazon-sagemaker-examples/tree/master/sagemaker-python-sdk). In order to test our algorithm, we need our dataset.

# %% [markdown]
# ## SageMaker Python SDK Local Training
# To represent our training, we use the Estimator class, which needs to be configured in five steps.
# 1. IAM role - our AWS execution role
# 2. train_instance_count - number of instances to use for training.
# 3. train_instance_type - type of instance to use for training. For training locally, we specify `local`.
# 4. image_name - our custom TensorFlow Docker image we created.
# 5. hyperparameters - hyperparameters we want to pass.
#
# Let's start with setting up our IAM role. We make use of a helper function within the Python SDK. This function throw an exception if run outside of a SageMaker notebook instance, as it gets metadata from the notebook instance. If running outside, you must provide an IAM role with proper access stated above in [Permissions](#Permissions).

# %%
from sagemaker import get_execution_role

role = get_execution_role()

# %%
hyperparameters = {'num_train_epochs': 1}

# %% [markdown]
# ## Fit, Deploy, Predict
#
# Now that the rest of our estimator is configured, we can call `fit()` with the path to our local CIFAR10 dataset prefixed with `file://`. This invokes our TensorFlow container with 'train' and passes in our hyperparameters and other metadata as json files in /opt/ml/input/config within the container.
#
# After our training has succeeded, our training algorithm outputs our trained model within the /opt/ml/model directory, which is used to handle predictions.
#
# We can then call `deploy()` with an instance_count and instance_type, which is 1 and `local`. This invokes our Tensorflow container with 'serve', which setups our container to handle prediction requests through TensorFlow Serving. What is returned is a predictor, which is used to make inferences against our trained model.
#
# After our prediction, we can delete our endpoint.
#
# We recommend testing and training your training algorithm locally first, as it provides quicker iterations and better debuggability.

# %%
# Lets set up our SageMaker notebook instance for local mode.
# !/bin/bash ./utils/setup.sh
# Out:
# The user has root access.
# SageMaker instance route table setup is ok. We are good to go.
# SageMaker instance routing for Docker is ok. We are good to go!

# %%
from sagemaker.estimator import Estimator
import subprocess

instance_type = 'local'

if subprocess.call('nvidia-smi') == 0:
    ## Set type to GPU if one is present
    instance_type = 'local_gpu'
    
print("Instance type = " + instance_type)

estimator = Estimator(role=role,
                      instance_count=1,
                      instance_type=instance_type,
                      image_uri='jittor:latest',
                      hyperparameters=hyperparameters)

estimator.fit({'training': 'file:///home/ec2-user/SageMaker/jittor_sagemaker/'})
# Out:
# Instance type = local
# Creating krfgwkdenc-algo-1-hfrjq ...
# Creating krfgwkdenc-algo-1-hfrjq ... done
# Attaching to krfgwkdenc-algo-1-hfrjq
# krfgwkdenc-algo-1-hfrjq | train_cmd: ['/usr/bin/python3.7', 'train.py', '--model-dir', '/opt/ml/model', '--num_train_epochs', '1']
# krfgwkdenc-algo-1-hfrjq | [i 0518 06:44:28.710814 32 compiler.py:851] Jittor(1.2.3.8) src: /usr/local/lib/python3.7/dist-packages/jittor
# krfgwkdenc-algo-1-hfrjq | [i 0518 06:44:28.710905 32 compiler.py:852] g++ at /usr/bin/g++
# krfgwkdenc-algo-1-hfrjq | [i 0518 06:44:28.710979 32 compiler.py:853] cache_path: /root/.cache/jittor/default/g++
# krfgwkdenc-algo-1-hfrjq | [i 0518 06:44:28.718691 32 __init__.py:255] Found addr2line(2.30) at /usr/bin/addr2line.
# krfgwkdenc-algo-1-hfrjq | [i 0518 06:44:28.727418 32 compiler.py:893] py_include: -I/usr/include/python3.7m -I/usr/include/python3.7m
# krfgwkdenc-algo-1-hfrjq | [i 0518 06:44:28.735766 32 compiler.py:895] extension_suffix: .cpython-37m-x86_64-linux-gnu.so
# krfgwkdenc-algo-1-hfrjq | [i 0518 06:44:28.845187 32 compiler.py:1014] OS type:ubuntu OS key:ubuntu
# krfgwkdenc-algo-1-hfrjq | [i 0518 06:44:28.847203 32 __init__.py:167] Total mem: 15.21GB, using 5 procs for compiling.
# krfgwkdenc-algo-1-hfrjq | [i 0518 06:44:28.943246 32 jit_compiler.cc:21] Load cc_path: /usr/bin/g++
# krfgwkdenc-algo-1-hfrjq | [i 0518 06:44:29.051056 32 __init__.py:255] Found mpicc(2.1.1) at /usr/bin/mpicc.
# krfgwkdenc-algo-1-hfrjq | [i 0518 06:44:29.066246 32 compiler.py:658] handle pyjt_include/usr/local/lib/python3.7/dist-packages/jittor/extern/mpi/inc/mpi_warper.h
# krfgwkdenc-algo-1-hfrjq |
# krfgwkdenc-algo-1-hfrjq | Compiling Operators(9/9) used: 2.31s eta:    0s
# krfgwkdenc-algo-1-hfrjq | step 0, loss = 0.2336575984954834
# krfgwkdenc-algo-1-hfrjq |
# krfgwkdenc-algo-1-hfrjq | Compiling Operators(14/14) used: 2.32s eta:    0s
# krfgwkdenc-algo-1-hfrjq | step 1, loss = 0.15834906697273254
# krfgwkdenc-algo-1-hfrjq | step 2, loss = 0.15285640954971313
# krfgwkdenc-algo-1-hfrjq | step 3, loss = 0.11027270555496216
# krfgwkdenc-algo-1-hfrjq | step 4, loss = 0.15378473699092865
# krfgwkdenc-algo-1-hfrjq | step 5, loss = 0.1087069883942604
# krfgwkdenc-algo-1-hfrjq | step 6, loss = 0.11347685754299164
# krfgwkdenc-algo-1-hfrjq | step 7, loss = 0.12057334184646606
# krfgwkdenc-algo-1-hfrjq | step 8, loss = 0.10222179442644119
# krfgwkdenc-algo-1-hfrjq | step 9, loss = 0.0908859595656395
# krfgwkdenc-algo-1-hfrjq | step 10, loss = 0.10658673942089081
# krfgwkdenc-algo-1-hfrjq | step 11, loss = 0.0845787301659584
# krfgwkdenc-algo-1-hfrjq | step 12, loss = 0.10037167370319366
# krfgwkdenc-algo-1-hfrjq | step 13, loss = 0.09048611670732498
# krfgwkdenc-algo-1-hfrjq | step 14, loss = 0.0972704365849495
# krfgwkdenc-algo-1-hfrjq | step 15, loss = 0.07944095134735107
# krfgwkdenc-algo-1-hfrjq | step 16, loss = 0.0702599361538887
# krfgwkdenc-algo-1-hfrjq | step 17, loss = 0.0955042839050293
# krfgwkdenc-algo-1-hfrjq | step 18, loss = 0.07579152286052704
# krfgwkdenc-algo-1-hfrjq | step 19, loss = 0.07622156292200089
# krfgwkdenc-algo-1-hfrjq | step 20, loss = 0.08443094789981842
# krfgwkdenc-algo-1-hfrjq | step 21, loss = 0.07286004722118378
# krfgwkdenc-algo-1-hfrjq | step 22, loss = 0.0835246667265892
# krfgwkdenc-algo-1-hfrjq | step 23, loss = 0.07769177109003067
# krfgwkdenc-algo-1-hfrjq | step 24, loss = 0.04884764552116394
# krfgwkdenc-algo-1-hfrjq | step 25, loss = 0.06345222145318985
# krfgwkdenc-algo-1-hfrjq | step 26, loss = 0.06955923140048981
# krfgwkdenc-algo-1-hfrjq | step 27, loss = 0.06479228287935257
# krfgwkdenc-algo-1-hfrjq | step 28, loss = 0.06964357197284698
# krfgwkdenc-algo-1-hfrjq | step 29, loss = 0.06730490177869797
# krfgwkdenc-algo-1-hfrjq | step 30, loss = 0.06967908143997192
# krfgwkdenc-algo-1-hfrjq | step 31, loss = 0.05500981956720352
# krfgwkdenc-algo-1-hfrjq | step 32, loss = 0.060838114470243454
# krfgwkdenc-algo-1-hfrjq | step 33, loss = 0.05749483406543732
# krfgwkdenc-algo-1-hfrjq | step 34, loss = 0.05209853872656822
# krfgwkdenc-algo-1-hfrjq | step 35, loss = 0.07043183594942093
# krfgwkdenc-algo-1-hfrjq | step 36, loss = 0.056358613073825836
# krfgwkdenc-algo-1-hfrjq | step 37, loss = 0.052090827375650406
# krfgwkdenc-algo-1-hfrjq | step 38, loss = 0.04631979763507843
# krfgwkdenc-algo-1-hfrjq | step 39, loss = 0.056140922009944916
# krfgwkdenc-algo-1-hfrjq | step 40, loss = 0.04093104973435402
# krfgwkdenc-algo-1-hfrjq | step 41, loss = 0.054204270243644714
# krfgwkdenc-algo-1-hfrjq | step 42, loss = 0.04024481028318405
# krfgwkdenc-algo-1-hfrjq | step 43, loss = 0.04196098446846008
# krfgwkdenc-algo-1-hfrjq | step 44, loss = 0.040333859622478485
# krfgwkdenc-algo-1-hfrjq | step 45, loss = 0.03677820786833763
# krfgwkdenc-algo-1-hfrjq | step 46, loss = 0.034341465681791306
# krfgwkdenc-algo-1-hfrjq | step 47, loss = 0.04111596196889877
# krfgwkdenc-algo-1-hfrjq | step 48, loss = 0.02778519317507744
# krfgwkdenc-algo-1-hfrjq | step 49, loss = 0.04022986814379692
# krfgwkdenc-algo-1-hfrjq | step 50, loss = 0.04395646974444389
# krfgwkdenc-algo-1-hfrjq | step 51, loss = 0.0357743538916111
# krfgwkdenc-algo-1-hfrjq | step 52, loss = 0.03454442694783211
# krfgwkdenc-algo-1-hfrjq | step 53, loss = 0.03383266553282738
# krfgwkdenc-algo-1-hfrjq | step 54, loss = 0.04050222411751747
# krfgwkdenc-algo-1-hfrjq | step 55, loss = 0.033456504344940186
# krfgwkdenc-algo-1-hfrjq | step 56, loss = 0.030736351385712624
# krfgwkdenc-algo-1-hfrjq | step 57, loss = 0.03056645765900612
# krfgwkdenc-algo-1-hfrjq | step 58, loss = 0.027142031118273735
# krfgwkdenc-algo-1-hfrjq | step 59, loss = 0.025573818013072014
# krfgwkdenc-algo-1-hfrjq | step 60, loss = 0.02319384180009365
# krfgwkdenc-algo-1-hfrjq | step 61, loss = 0.019174868240952492
# krfgwkdenc-algo-1-hfrjq | step 62, loss = 0.01870359107851982
# krfgwkdenc-algo-1-hfrjq | step 63, loss = 0.023872843012213707
# krfgwkdenc-algo-1-hfrjq | step 64, loss = 0.021716689690947533
# krfgwkdenc-algo-1-hfrjq | step 65, loss = 0.020796386525034904
# krfgwkdenc-algo-1-hfrjq | step 66, loss = 0.017137454822659492
# krfgwkdenc-algo-1-hfrjq | step 67, loss = 0.034189678728580475
# krfgwkdenc-algo-1-hfrjq | step 68, loss = 0.02452842704951763
# krfgwkdenc-algo-1-hfrjq | step 69, loss = 0.014660395681858063
# krfgwkdenc-algo-1-hfrjq | step 70, loss = 0.02141350880265236
# krfgwkdenc-algo-1-hfrjq | step 71, loss = 0.02174435369670391
# krfgwkdenc-algo-1-hfrjq | step 72, loss = 0.018058372661471367
# krfgwkdenc-algo-1-hfrjq | step 73, loss = 0.014836546964943409
# krfgwkdenc-algo-1-hfrjq | step 74, loss = 0.017756564542651176
# krfgwkdenc-algo-1-hfrjq | step 75, loss = 0.02734251506626606
# krfgwkdenc-algo-1-hfrjq | step 76, loss = 0.018321774899959564
# krfgwkdenc-algo-1-hfrjq | step 77, loss = 0.014866657555103302
# krfgwkdenc-algo-1-hfrjq | step 78, loss = 0.01922987587749958
# krfgwkdenc-algo-1-hfrjq | step 79, loss = 0.01306058093905449
# krfgwkdenc-algo-1-hfrjq | step 80, loss = 0.013671471737325191
# krfgwkdenc-algo-1-hfrjq | step 81, loss = 0.016891758888959885
# krfgwkdenc-algo-1-hfrjq | step 82, loss = 0.01991325616836548
# krfgwkdenc-algo-1-hfrjq | step 83, loss = 0.014091196469962597
# krfgwkdenc-algo-1-hfrjq | step 84, loss = 0.01133026648312807
# krfgwkdenc-algo-1-hfrjq | step 85, loss = 0.018613353371620178
# krfgwkdenc-algo-1-hfrjq | step 86, loss = 0.014134353958070278
# krfgwkdenc-algo-1-hfrjq | step 87, loss = 0.010672276839613914
# krfgwkdenc-algo-1-hfrjq | step 88, loss = 0.013581628911197186
# krfgwkdenc-algo-1-hfrjq | step 89, loss = 0.015113269910216331
# krfgwkdenc-algo-1-hfrjq | step 90, loss = 0.013545317575335503
# krfgwkdenc-algo-1-hfrjq | step 91, loss = 0.008924279361963272
# krfgwkdenc-algo-1-hfrjq | step 92, loss = 0.00889882817864418
# krfgwkdenc-algo-1-hfrjq | step 93, loss = 0.01283442322164774
# krfgwkdenc-algo-1-hfrjq | step 94, loss = 0.01082505751401186
# krfgwkdenc-algo-1-hfrjq | step 95, loss = 0.008750484324991703
# krfgwkdenc-algo-1-hfrjq | step 96, loss = 0.012846702709794044
# krfgwkdenc-algo-1-hfrjq | step 97, loss = 0.010705043561756611
# krfgwkdenc-algo-1-hfrjq | step 98, loss = 0.008693549782037735
# krfgwkdenc-algo-1-hfrjq | step 99, loss = 0.006969924550503492
# krfgwkdenc-algo-1-hfrjq | step 100, loss = 0.009851878508925438
# krfgwkdenc-algo-1-hfrjq | step 101, loss = 0.009636328555643559
# krfgwkdenc-algo-1-hfrjq | step 102, loss = 0.009494064375758171
# krfgwkdenc-algo-1-hfrjq | step 103, loss = 0.009077558293938637
# krfgwkdenc-algo-1-hfrjq | step 104, loss = 0.010290553793311119
# krfgwkdenc-algo-1-hfrjq | step 105, loss = 0.007265391293913126
# krfgwkdenc-algo-1-hfrjq | step 106, loss = 0.0112855089828372
# krfgwkdenc-algo-1-hfrjq | step 107, loss = 0.007734275888651609
# krfgwkdenc-algo-1-hfrjq | step 108, loss = 0.007357540540397167
# krfgwkdenc-algo-1-hfrjq | step 109, loss = 0.007641520816832781
# krfgwkdenc-algo-1-hfrjq | step 110, loss = 0.006130197551101446
# krfgwkdenc-algo-1-hfrjq | step 111, loss = 0.00850997306406498
# krfgwkdenc-algo-1-hfrjq | step 112, loss = 0.009654776193201542
# krfgwkdenc-algo-1-hfrjq | step 113, loss = 0.007273264229297638
# krfgwkdenc-algo-1-hfrjq | step 114, loss = 0.008093503303825855
# krfgwkdenc-algo-1-hfrjq | step 115, loss = 0.007920080795884132
# krfgwkdenc-algo-1-hfrjq | step 116, loss = 0.006920148618519306
# krfgwkdenc-algo-1-hfrjq | step 117, loss = 0.008759502321481705
# krfgwkdenc-algo-1-hfrjq | step 118, loss = 0.00827435590326786
# krfgwkdenc-algo-1-hfrjq | step 119, loss = 0.00632609473541379
# krfgwkdenc-algo-1-hfrjq | step 120, loss = 0.007683302275836468
# krfgwkdenc-algo-1-hfrjq | step 121, loss = 0.006711085792630911
# krfgwkdenc-algo-1-hfrjq | step 122, loss = 0.006736408919095993
# krfgwkdenc-algo-1-hfrjq | step 123, loss = 0.0073137166909873486
# krfgwkdenc-algo-1-hfrjq | step 124, loss = 0.005618271883577108
# krfgwkdenc-algo-1-hfrjq | step 125, loss = 0.005434260703623295
# krfgwkdenc-algo-1-hfrjq | step 126, loss = 0.00495765870437026
# krfgwkdenc-algo-1-hfrjq | step 127, loss = 0.005369322374463081
# krfgwkdenc-algo-1-hfrjq | step 128, loss = 0.005608213134109974
# krfgwkdenc-algo-1-hfrjq | step 129, loss = 0.006999511271715164
# krfgwkdenc-algo-1-hfrjq | step 130, loss = 0.00482260063290596
# krfgwkdenc-algo-1-hfrjq | step 131, loss = 0.0075480155646800995
# krfgwkdenc-algo-1-hfrjq | step 132, loss = 0.004456050228327513
# krfgwkdenc-algo-1-hfrjq | step 133, loss = 0.005546306259930134
# krfgwkdenc-algo-1-hfrjq | step 134, loss = 0.006219883449375629
# krfgwkdenc-algo-1-hfrjq | step 135, loss = 0.006206533405929804
# krfgwkdenc-algo-1-hfrjq | step 136, loss = 0.0077043212950229645
# krfgwkdenc-algo-1-hfrjq | step 137, loss = 0.006404682993888855
# krfgwkdenc-algo-1-hfrjq | step 138, loss = 0.007588806562125683
# krfgwkdenc-algo-1-hfrjq | step 139, loss = 0.004756698850542307
# krfgwkdenc-algo-1-hfrjq | step 140, loss = 0.005232236813753843
# krfgwkdenc-algo-1-hfrjq | step 141, loss = 0.004353803116828203
# krfgwkdenc-algo-1-hfrjq | step 142, loss = 0.005001079756766558
# krfgwkdenc-algo-1-hfrjq | step 143, loss = 0.005248666275292635
# krfgwkdenc-algo-1-hfrjq | step 144, loss = 0.004952790681272745
# krfgwkdenc-algo-1-hfrjq | step 145, loss = 0.005513297859579325
# krfgwkdenc-algo-1-hfrjq | step 146, loss = 0.005044194869697094
# krfgwkdenc-algo-1-hfrjq | step 147, loss = 0.004552297294139862
# krfgwkdenc-algo-1-hfrjq | step 148, loss = 0.006896959152072668
# krfgwkdenc-algo-1-hfrjq | step 149, loss = 0.006725652143359184
# krfgwkdenc-algo-1-hfrjq | step 150, loss = 0.006613605655729771
# krfgwkdenc-algo-1-hfrjq | step 151, loss = 0.004329948220402002
# krfgwkdenc-algo-1-hfrjq | step 152, loss = 0.005160338245332241
# krfgwkdenc-algo-1-hfrjq | step 153, loss = 0.004161774646490812
# krfgwkdenc-algo-1-hfrjq | step 154, loss = 0.006579498760402203
# krfgwkdenc-algo-1-hfrjq | step 155, loss = 0.0051865046843886375
# krfgwkdenc-algo-1-hfrjq | step 156, loss = 0.003421225119382143
# krfgwkdenc-algo-1-hfrjq | step 157, loss = 0.00774766318500042
# krfgwkdenc-algo-1-hfrjq | step 158, loss = 0.005464544054120779
# krfgwkdenc-algo-1-hfrjq | step 159, loss = 0.005539290141314268
# krfgwkdenc-algo-1-hfrjq | step 160, loss = 0.004386440850794315
# krfgwkdenc-algo-1-hfrjq | step 161, loss = 0.004414183087646961
# krfgwkdenc-algo-1-hfrjq | step 162, loss = 0.004807806573808193
# krfgwkdenc-algo-1-hfrjq | step 163, loss = 0.0037031699903309345
# krfgwkdenc-algo-1-hfrjq | step 164, loss = 0.005583471618592739
# krfgwkdenc-algo-1-hfrjq | step 165, loss = 0.005961209069937468
# krfgwkdenc-algo-1-hfrjq | step 166, loss = 0.004501395858824253
# krfgwkdenc-algo-1-hfrjq | step 167, loss = 0.00509816687554121
# krfgwkdenc-algo-1-hfrjq | step 168, loss = 0.0032646425534039736
# krfgwkdenc-algo-1-hfrjq | step 169, loss = 0.005893486551940441
# krfgwkdenc-algo-1-hfrjq | step 170, loss = 0.004242542199790478
# krfgwkdenc-algo-1-hfrjq | step 171, loss = 0.006205015350133181
# krfgwkdenc-algo-1-hfrjq | step 172, loss = 0.00397475017234683
# krfgwkdenc-algo-1-hfrjq | step 173, loss = 0.004841938614845276
# krfgwkdenc-algo-1-hfrjq | step 174, loss = 0.004263918846845627
# krfgwkdenc-algo-1-hfrjq | step 175, loss = 0.005166968796402216
# krfgwkdenc-algo-1-hfrjq | step 176, loss = 0.004665873944759369
# krfgwkdenc-algo-1-hfrjq | step 177, loss = 0.003785979002714157
# krfgwkdenc-algo-1-hfrjq | step 178, loss = 0.004536334425210953
# krfgwkdenc-algo-1-hfrjq | step 179, loss = 0.003579499665647745
# krfgwkdenc-algo-1-hfrjq | step 180, loss = 0.005127489101141691
# krfgwkdenc-algo-1-hfrjq | step 181, loss = 0.003932807594537735
# krfgwkdenc-algo-1-hfrjq | step 182, loss = 0.00329895643517375
# krfgwkdenc-algo-1-hfrjq | step 183, loss = 0.003657724242657423
# krfgwkdenc-algo-1-hfrjq | step 184, loss = 0.0037895250134170055
# krfgwkdenc-algo-1-hfrjq | step 185, loss = 0.003975641448050737
# krfgwkdenc-algo-1-hfrjq | step 186, loss = 0.003023972036316991
# krfgwkdenc-algo-1-hfrjq | step 187, loss = 0.002908801892772317
# krfgwkdenc-algo-1-hfrjq | step 188, loss = 0.004486188758164644
# krfgwkdenc-algo-1-hfrjq | step 189, loss = 0.005052316468209028
# krfgwkdenc-algo-1-hfrjq | step 190, loss = 0.0038520994130522013
# krfgwkdenc-algo-1-hfrjq | step 191, loss = 0.004286563489586115
# krfgwkdenc-algo-1-hfrjq | step 192, loss = 0.0035112062469124794
# krfgwkdenc-algo-1-hfrjq | step 193, loss = 0.0029157972894608974
# krfgwkdenc-algo-1-hfrjq | step 194, loss = 0.0026135677471756935
# krfgwkdenc-algo-1-hfrjq | step 195, loss = 0.003901019226759672
# krfgwkdenc-algo-1-hfrjq | step 196, loss = 0.0031767068430781364
# krfgwkdenc-algo-1-hfrjq | step 197, loss = 0.004409693647176027
# krfgwkdenc-algo-1-hfrjq | step 198, loss = 0.0044126687571406364
# krfgwkdenc-algo-1-hfrjq | step 199, loss = 0.0028202226385474205
# krfgwkdenc-algo-1-hfrjq | step 200, loss = 0.0031363151501864195
# krfgwkdenc-algo-1-hfrjq | step 201, loss = 0.0036729418206959963
# krfgwkdenc-algo-1-hfrjq | step 202, loss = 0.0037181011866778135
# krfgwkdenc-algo-1-hfrjq | step 203, loss = 0.004793505184352398
# krfgwkdenc-algo-1-hfrjq | step 204, loss = 0.0034966215025633574
# krfgwkdenc-algo-1-hfrjq | step 205, loss = 0.003636579494923353
# krfgwkdenc-algo-1-hfrjq | step 206, loss = 0.004530207719653845
# krfgwkdenc-algo-1-hfrjq | step 207, loss = 0.0033717832993716
# krfgwkdenc-algo-1-hfrjq | step 208, loss = 0.003966628108173609
# krfgwkdenc-algo-1-hfrjq | step 209, loss = 0.003289573360234499
# krfgwkdenc-algo-1-hfrjq | step 210, loss = 0.0036280392669141293
# krfgwkdenc-algo-1-hfrjq | step 211, loss = 0.0028942085336893797
# krfgwkdenc-algo-1-hfrjq | step 212, loss = 0.003124639857560396
# krfgwkdenc-algo-1-hfrjq | step 213, loss = 0.004702595062553883
# krfgwkdenc-algo-1-hfrjq | step 214, loss = 0.0035771590191870928
# krfgwkdenc-algo-1-hfrjq | step 215, loss = 0.003553545568138361
# krfgwkdenc-algo-1-hfrjq | step 216, loss = 0.004344814922660589
# krfgwkdenc-algo-1-hfrjq | step 217, loss = 0.0025674004573374987
# krfgwkdenc-algo-1-hfrjq | step 218, loss = 0.0023640140425413847
# krfgwkdenc-algo-1-hfrjq | step 219, loss = 0.0032827851828187704
# krfgwkdenc-algo-1-hfrjq | step 220, loss = 0.0032352281268686056
# krfgwkdenc-algo-1-hfrjq | step 221, loss = 0.0033454031217843294
# krfgwkdenc-algo-1-hfrjq | step 222, loss = 0.002490923274308443
# krfgwkdenc-algo-1-hfrjq | step 223, loss = 0.004167228005826473
# krfgwkdenc-algo-1-hfrjq | step 224, loss = 0.0038749058730900288
# krfgwkdenc-algo-1-hfrjq | step 225, loss = 0.0024535355623811483
# krfgwkdenc-algo-1-hfrjq | step 226, loss = 0.002845379523932934
# krfgwkdenc-algo-1-hfrjq | step 227, loss = 0.0036868052557110786
# krfgwkdenc-algo-1-hfrjq | step 228, loss = 0.003068236168473959
# krfgwkdenc-algo-1-hfrjq | step 229, loss = 0.003322150558233261
# krfgwkdenc-algo-1-hfrjq | step 230, loss = 0.00209290673956275
# krfgwkdenc-algo-1-hfrjq | step 231, loss = 0.0034437093418091536
# krfgwkdenc-algo-1-hfrjq | step 232, loss = 0.00236984109506011
# krfgwkdenc-algo-1-hfrjq | step 233, loss = 0.0033168208319693804
# krfgwkdenc-algo-1-hfrjq | step 234, loss = 0.002254868857562542
# krfgwkdenc-algo-1-hfrjq | step 235, loss = 0.003090511541813612
# krfgwkdenc-algo-1-hfrjq | step 236, loss = 0.0025092214345932007
# krfgwkdenc-algo-1-hfrjq | step 237, loss = 0.0026944077108055353
# krfgwkdenc-algo-1-hfrjq | step 238, loss = 0.0021773572079837322
# krfgwkdenc-algo-1-hfrjq | step 239, loss = 0.003180508268997073
# krfgwkdenc-algo-1-hfrjq | step 240, loss = 0.0025391243398189545
# krfgwkdenc-algo-1-hfrjq | step 241, loss = 0.0027578251902014017
# krfgwkdenc-algo-1-hfrjq | step 242, loss = 0.0023125160951167345
# krfgwkdenc-algo-1-hfrjq | step 243, loss = 0.0031638655345886946
# krfgwkdenc-algo-1-hfrjq | step 244, loss = 0.0025932330172508955
# krfgwkdenc-algo-1-hfrjq | step 245, loss = 0.00270048133097589
# krfgwkdenc-algo-1-hfrjq | step 246, loss = 0.002922126790508628
# krfgwkdenc-algo-1-hfrjq | step 247, loss = 0.0017672204412519932
# krfgwkdenc-algo-1-hfrjq | step 248, loss = 0.0016833640402182937
# krfgwkdenc-algo-1-hfrjq | step 249, loss = 0.0025021506007760763
# krfgwkdenc-algo-1-hfrjq | step 250, loss = 0.0032175604719668627
# krfgwkdenc-algo-1-hfrjq | step 251, loss = 0.003905310295522213
# krfgwkdenc-algo-1-hfrjq | step 252, loss = 0.0022853012196719646
# krfgwkdenc-algo-1-hfrjq | step 253, loss = 0.001924881711602211
# krfgwkdenc-algo-1-hfrjq | step 254, loss = 0.002787878969684243
# krfgwkdenc-algo-1-hfrjq | step 255, loss = 0.0029952889308333397
# krfgwkdenc-algo-1-hfrjq | step 256, loss = 0.0021114565897732973
# krfgwkdenc-algo-1-hfrjq | step 257, loss = 0.003292894223704934
# krfgwkdenc-algo-1-hfrjq | step 258, loss = 0.0023416473995894194
# krfgwkdenc-algo-1-hfrjq | step 259, loss = 0.002327313181012869
# krfgwkdenc-algo-1-hfrjq | step 260, loss = 0.0026496334467083216
# krfgwkdenc-algo-1-hfrjq | step 261, loss = 0.0023526528384536505
# krfgwkdenc-algo-1-hfrjq | step 262, loss = 0.0034473612904548645
# krfgwkdenc-algo-1-hfrjq | step 263, loss = 0.0032415930181741714
# krfgwkdenc-algo-1-hfrjq | step 264, loss = 0.00286325765773654
# krfgwkdenc-algo-1-hfrjq | step 265, loss = 0.0028405715711414814
# krfgwkdenc-algo-1-hfrjq | step 266, loss = 0.001810229616239667
# krfgwkdenc-algo-1-hfrjq | step 267, loss = 0.0020680741872638464
# krfgwkdenc-algo-1-hfrjq | step 268, loss = 0.002367437118664384
# krfgwkdenc-algo-1-hfrjq | step 269, loss = 0.002150480868294835
# krfgwkdenc-algo-1-hfrjq | step 270, loss = 0.002589327748864889
# krfgwkdenc-algo-1-hfrjq | step 271, loss = 0.0017720015021041036
# krfgwkdenc-algo-1-hfrjq | step 272, loss = 0.0020183883607387543
# krfgwkdenc-algo-1-hfrjq | step 273, loss = 0.0013297731056809425
# krfgwkdenc-algo-1-hfrjq | step 274, loss = 0.0017564480658620596
# krfgwkdenc-algo-1-hfrjq | step 275, loss = 0.0011079064570367336
# krfgwkdenc-algo-1-hfrjq | step 276, loss = 0.002167714759707451
# krfgwkdenc-algo-1-hfrjq | step 277, loss = 0.002462174044921994
# krfgwkdenc-algo-1-hfrjq | step 278, loss = 0.0024309144355356693
# krfgwkdenc-algo-1-hfrjq | step 279, loss = 0.0022766017355024815
# krfgwkdenc-algo-1-hfrjq | step 280, loss = 0.002147500868886709
# krfgwkdenc-algo-1-hfrjq | step 281, loss = 0.002506728982552886
# krfgwkdenc-algo-1-hfrjq | step 282, loss = 0.002425173996016383
# krfgwkdenc-algo-1-hfrjq | step 283, loss = 0.0017471028259024024
# krfgwkdenc-algo-1-hfrjq | step 284, loss = 0.0018621670315042138
# krfgwkdenc-algo-1-hfrjq | step 285, loss = 0.002115141600370407
# krfgwkdenc-algo-1-hfrjq | step 286, loss = 0.0019442243501543999
# krfgwkdenc-algo-1-hfrjq | step 287, loss = 0.0015432290965691209
# krfgwkdenc-algo-1-hfrjq | step 288, loss = 0.0022684282157570124
# krfgwkdenc-algo-1-hfrjq | step 289, loss = 0.0023357910104095936
# krfgwkdenc-algo-1-hfrjq | step 290, loss = 0.002395763760432601
# krfgwkdenc-algo-1-hfrjq | step 291, loss = 0.002764879260212183
# krfgwkdenc-algo-1-hfrjq | step 292, loss = 0.0025201933458447456
# krfgwkdenc-algo-1-hfrjq | step 293, loss = 0.0012779260287061334
# krfgwkdenc-algo-1-hfrjq | step 294, loss = 0.0020625826437026262
# krfgwkdenc-algo-1-hfrjq | step 295, loss = 0.0015327963046729565
# krfgwkdenc-algo-1-hfrjq | step 296, loss = 0.0017806708347052336
# krfgwkdenc-algo-1-hfrjq | step 297, loss = 0.0018016485264524817
# krfgwkdenc-algo-1-hfrjq | step 298, loss = 0.0018368912860751152
# krfgwkdenc-algo-1-hfrjq | step 299, loss = 0.0021353173069655895
# krfgwkdenc-algo-1-hfrjq | step 300, loss = 0.0016953052254393697
# krfgwkdenc-algo-1-hfrjq | step 301, loss = 0.0018024260643869638
# krfgwkdenc-algo-1-hfrjq | step 302, loss = 0.0021000318229198456
# krfgwkdenc-algo-1-hfrjq | step 303, loss = 0.0017308099195361137
# krfgwkdenc-algo-1-hfrjq | step 304, loss = 0.0013872202252969146
# krfgwkdenc-algo-1-hfrjq | step 305, loss = 0.001433757832273841
# krfgwkdenc-algo-1-hfrjq | step 306, loss = 0.001530826441012323
# krfgwkdenc-algo-1-hfrjq | step 307, loss = 0.0020987156312912703
# krfgwkdenc-algo-1-hfrjq | step 308, loss = 0.0029735208954662085
# krfgwkdenc-algo-1-hfrjq | step 309, loss = 0.0018757575890049338
# krfgwkdenc-algo-1-hfrjq | step 310, loss = 0.001451556570827961
# krfgwkdenc-algo-1-hfrjq | step 311, loss = 0.0015821827109903097
# krfgwkdenc-algo-1-hfrjq | step 312, loss = 0.002648040419444442
# krfgwkdenc-algo-1-hfrjq | step 313, loss = 0.0017025003908202052
# krfgwkdenc-algo-1-hfrjq | step 314, loss = 0.0014792720321565866
# krfgwkdenc-algo-1-hfrjq | step 315, loss = 0.002283836016431451
# krfgwkdenc-algo-1-hfrjq | step 316, loss = 0.0015573407290503383
# krfgwkdenc-algo-1-hfrjq | step 317, loss = 0.0019200099632143974
# krfgwkdenc-algo-1-hfrjq | step 318, loss = 0.0016428751405328512
# krfgwkdenc-algo-1-hfrjq | step 319, loss = 0.0020056129433214664
# krfgwkdenc-algo-1-hfrjq | step 320, loss = 0.0019162575481459498
# krfgwkdenc-algo-1-hfrjq | step 321, loss = 0.001792132155969739
# krfgwkdenc-algo-1-hfrjq | step 322, loss = 0.001917817397043109
# krfgwkdenc-algo-1-hfrjq | step 323, loss = 0.0012234699679538608
# krfgwkdenc-algo-1-hfrjq | step 324, loss = 0.0018472918309271336
# krfgwkdenc-algo-1-hfrjq | step 325, loss = 0.0016174191841855645
# krfgwkdenc-algo-1-hfrjq | step 326, loss = 0.0015017841942608356
# krfgwkdenc-algo-1-hfrjq | step 327, loss = 0.0018139593303203583
# krfgwkdenc-algo-1-hfrjq | step 328, loss = 0.001953867031261325
# krfgwkdenc-algo-1-hfrjq | step 329, loss = 0.0021791348699480295
# krfgwkdenc-algo-1-hfrjq | step 330, loss = 0.0017630868824198842
# krfgwkdenc-algo-1-hfrjq | step 331, loss = 0.0014360183849930763
# krfgwkdenc-algo-1-hfrjq | step 332, loss = 0.0018715659389272332
# krfgwkdenc-algo-1-hfrjq | step 333, loss = 0.001892309752292931
# krfgwkdenc-algo-1-hfrjq | step 334, loss = 0.0016424184432253242
# krfgwkdenc-algo-1-hfrjq | step 335, loss = 0.0014939839020371437
# krfgwkdenc-algo-1-hfrjq | step 336, loss = 0.0017907244618982077
# krfgwkdenc-algo-1-hfrjq | step 337, loss = 0.0012288907309994102
# krfgwkdenc-algo-1-hfrjq | step 338, loss = 0.0012766157742589712
# krfgwkdenc-algo-1-hfrjq | step 339, loss = 0.0014308723621070385
# krfgwkdenc-algo-1-hfrjq | step 340, loss = 0.001375707914121449
# krfgwkdenc-algo-1-hfrjq | step 341, loss = 0.001264212653040886
# krfgwkdenc-algo-1-hfrjq | step 342, loss = 0.001349749625660479
# krfgwkdenc-algo-1-hfrjq | step 343, loss = 0.001568918232806027
# krfgwkdenc-algo-1-hfrjq | step 344, loss = 0.0011367236729711294
# krfgwkdenc-algo-1-hfrjq | step 345, loss = 0.0011756072053685784
# krfgwkdenc-algo-1-hfrjq | step 346, loss = 0.0009108514641411602
# krfgwkdenc-algo-1-hfrjq | step 347, loss = 0.0012309597805142403
# krfgwkdenc-algo-1-hfrjq | step 348, loss = 0.0011626032646745443
# krfgwkdenc-algo-1-hfrjq | step 349, loss = 0.001228217501193285
# krfgwkdenc-algo-1-hfrjq | step 350, loss = 0.0018901909934356809
# krfgwkdenc-algo-1-hfrjq | step 351, loss = 0.0014941728441044688
# krfgwkdenc-algo-1-hfrjq | step 352, loss = 0.001314683584496379
# krfgwkdenc-algo-1-hfrjq | step 353, loss = 0.0009630323038436472
# krfgwkdenc-algo-1-hfrjq | step 354, loss = 0.0021659396588802338
# krfgwkdenc-algo-1-hfrjq | step 355, loss = 0.001549787470139563
# krfgwkdenc-algo-1-hfrjq | step 356, loss = 0.0013287380570545793
# krfgwkdenc-algo-1-hfrjq | step 357, loss = 0.0011846978450194001
# krfgwkdenc-algo-1-hfrjq | step 358, loss = 0.0016499843914061785
# krfgwkdenc-algo-1-hfrjq | step 359, loss = 0.0010768469655886292
# krfgwkdenc-algo-1-hfrjq | step 360, loss = 0.0013291646027937531
# krfgwkdenc-algo-1-hfrjq | step 361, loss = 0.0009589017136022449
# krfgwkdenc-algo-1-hfrjq | step 362, loss = 0.0012127191293984652
# krfgwkdenc-algo-1-hfrjq | step 363, loss = 0.0019332533702254295
# krfgwkdenc-algo-1-hfrjq | step 364, loss = 0.0019486186793074012
# krfgwkdenc-algo-1-hfrjq | step 365, loss = 0.0012693757889792323
# krfgwkdenc-algo-1-hfrjq | step 366, loss = 0.0014864255208522081
# krfgwkdenc-algo-1-hfrjq | step 367, loss = 0.0011041492689400911
# krfgwkdenc-algo-1-hfrjq | step 368, loss = 0.0014440027298405766
# krfgwkdenc-algo-1-hfrjq | step 369, loss = 0.0011464128037914634
# krfgwkdenc-algo-1-hfrjq | step 370, loss = 0.0012000674614682794
# krfgwkdenc-algo-1-hfrjq | step 371, loss = 0.0012295348569750786
# krfgwkdenc-algo-1-hfrjq | step 372, loss = 0.0016542111989110708
# krfgwkdenc-algo-1-hfrjq | step 373, loss = 0.0010966617846861482
# krfgwkdenc-algo-1-hfrjq | step 374, loss = 0.0009576367447152734
# krfgwkdenc-algo-1-hfrjq | step 375, loss = 0.0008796332404017448
# krfgwkdenc-algo-1-hfrjq | step 376, loss = 0.0013630944304168224
# krfgwkdenc-algo-1-hfrjq | step 377, loss = 0.001432990306057036
# krfgwkdenc-algo-1-hfrjq | step 378, loss = 0.0010506578255444765
# krfgwkdenc-algo-1-hfrjq | step 379, loss = 0.0010345999617129564
# krfgwkdenc-algo-1-hfrjq | step 380, loss = 0.0019484040094539523
# krfgwkdenc-algo-1-hfrjq | step 381, loss = 0.0012332603801041842
# krfgwkdenc-algo-1-hfrjq | step 382, loss = 0.001013481174595654
# krfgwkdenc-algo-1-hfrjq | step 383, loss = 0.0011977278627455235
# krfgwkdenc-algo-1-hfrjq | step 384, loss = 0.0015600946499034762
# krfgwkdenc-algo-1-hfrjq | step 385, loss = 0.0013852146221324801
# krfgwkdenc-algo-1-hfrjq | step 386, loss = 0.0016088996781036258
# krfgwkdenc-algo-1-hfrjq | step 387, loss = 0.0013431101106107235
# krfgwkdenc-algo-1-hfrjq | step 388, loss = 0.0008289830875582993
# krfgwkdenc-algo-1-hfrjq | step 389, loss = 0.000734938308596611
# krfgwkdenc-algo-1-hfrjq | step 390, loss = 0.0013208421878516674
# krfgwkdenc-algo-1-hfrjq | step 391, loss = 0.001123695052228868
# krfgwkdenc-algo-1-hfrjq | step 392, loss = 0.0010474054142832756
# krfgwkdenc-algo-1-hfrjq | step 393, loss = 0.001142151653766632
# krfgwkdenc-algo-1-hfrjq | step 394, loss = 0.0011319443583488464
# krfgwkdenc-algo-1-hfrjq | step 395, loss = 0.001278876792639494
# krfgwkdenc-algo-1-hfrjq | step 396, loss = 0.001449138973839581
# krfgwkdenc-algo-1-hfrjq | step 397, loss = 0.0012901105219498277
# krfgwkdenc-algo-1-hfrjq | step 398, loss = 0.0007864372455514967
# krfgwkdenc-algo-1-hfrjq | step 399, loss = 0.0012148807290941477
# krfgwkdenc-algo-1-hfrjq | step 400, loss = 0.0013296430697664618
# krfgwkdenc-algo-1-hfrjq | step 401, loss = 0.001282547484152019
# krfgwkdenc-algo-1-hfrjq | step 402, loss = 0.001171417417936027
# krfgwkdenc-algo-1-hfrjq | step 403, loss = 0.001057279878295958
# krfgwkdenc-algo-1-hfrjq | step 404, loss = 0.0015374122885987163
# krfgwkdenc-algo-1-hfrjq | step 405, loss = 0.001235659816302359
# krfgwkdenc-algo-1-hfrjq | step 406, loss = 0.0007070018909871578
# krfgwkdenc-algo-1-hfrjq | step 407, loss = 0.0011975605739280581
# krfgwkdenc-algo-1-hfrjq | step 408, loss = 0.0014348863624036312
# krfgwkdenc-algo-1-hfrjq | step 409, loss = 0.0012349277967587113
# krfgwkdenc-algo-1-hfrjq | step 410, loss = 0.0012552564730867743
# krfgwkdenc-algo-1-hfrjq | step 411, loss = 0.0007437309832312167
# krfgwkdenc-algo-1-hfrjq | step 412, loss = 0.0015174882719293237
# krfgwkdenc-algo-1-hfrjq | step 413, loss = 0.0011484578717499971
# krfgwkdenc-algo-1-hfrjq | step 414, loss = 0.001392209785990417
# krfgwkdenc-algo-1-hfrjq | step 415, loss = 0.0011243781773373485
# krfgwkdenc-algo-1-hfrjq | step 416, loss = 0.0011870870366692543
# krfgwkdenc-algo-1-hfrjq | step 417, loss = 0.001160333980806172
# krfgwkdenc-algo-1-hfrjq | step 418, loss = 0.001245141145773232
# krfgwkdenc-algo-1-hfrjq | step 419, loss = 0.0011818022467195988
# krfgwkdenc-algo-1-hfrjq | step 420, loss = 0.0009362350101582706
# krfgwkdenc-algo-1-hfrjq | step 421, loss = 0.0013103003147989511
# krfgwkdenc-algo-1-hfrjq | step 422, loss = 0.0006771463085897267
# krfgwkdenc-algo-1-hfrjq | step 423, loss = 0.0014434255426749587
# krfgwkdenc-algo-1-hfrjq | step 424, loss = 0.0007966377888806164
# krfgwkdenc-algo-1-hfrjq | step 425, loss = 0.0008054755162447691
# krfgwkdenc-algo-1-hfrjq | step 426, loss = 0.0015059660654515028
# krfgwkdenc-algo-1-hfrjq | step 427, loss = 0.000990103231742978
# krfgwkdenc-algo-1-hfrjq | step 428, loss = 0.0008779459749348462
# krfgwkdenc-algo-1-hfrjq | step 429, loss = 0.000659445533528924
# krfgwkdenc-algo-1-hfrjq | step 430, loss = 0.0010062671499326825
# krfgwkdenc-algo-1-hfrjq | step 431, loss = 0.0005875058704987168
# krfgwkdenc-algo-1-hfrjq | step 432, loss = 0.0008905698196031153
# krfgwkdenc-algo-1-hfrjq | step 433, loss = 0.000981810037046671
# krfgwkdenc-algo-1-hfrjq | step 434, loss = 0.0012023873860016465
# krfgwkdenc-algo-1-hfrjq | step 435, loss = 0.000859058927744627
# krfgwkdenc-algo-1-hfrjq | step 436, loss = 0.0006081211031414568
# krfgwkdenc-algo-1-hfrjq | step 437, loss = 0.0012141690822318196
# krfgwkdenc-algo-1-hfrjq | step 438, loss = 0.0005948449834249914
# krfgwkdenc-algo-1-hfrjq | step 439, loss = 0.0013258594553917646
# krfgwkdenc-algo-1-hfrjq | step 440, loss = 0.0009518200531601906
# krfgwkdenc-algo-1-hfrjq | step 441, loss = 0.0010162987746298313
# krfgwkdenc-algo-1-hfrjq | step 442, loss = 0.0008667738875374198
# krfgwkdenc-algo-1-hfrjq | step 443, loss = 0.0007319878204725683
# krfgwkdenc-algo-1-hfrjq | step 444, loss = 0.0007264771265909076
# krfgwkdenc-algo-1-hfrjq | step 445, loss = 0.0009673500317148864
# krfgwkdenc-algo-1-hfrjq | step 446, loss = 0.0009277783683501184
# krfgwkdenc-algo-1-hfrjq | step 447, loss = 0.00033609214005991817
# krfgwkdenc-algo-1-hfrjq | step 448, loss = 0.0006965940119698644
# krfgwkdenc-algo-1-hfrjq | step 449, loss = 0.0009150172700174153
# krfgwkdenc-algo-1-hfrjq | step 450, loss = 0.0013631274923682213
# krfgwkdenc-algo-1-hfrjq | step 451, loss = 0.0012139825848862529
# krfgwkdenc-algo-1-hfrjq | step 452, loss = 0.001069332822225988
# krfgwkdenc-algo-1-hfrjq | step 453, loss = 0.0008893694030120969
# krfgwkdenc-algo-1-hfrjq | step 454, loss = 0.001253908732905984
# krfgwkdenc-algo-1-hfrjq | step 455, loss = 0.0010698934784159064
# krfgwkdenc-algo-1-hfrjq | step 456, loss = 0.0007510388386435807
# krfgwkdenc-algo-1-hfrjq | step 457, loss = 0.0009954150300472975
# krfgwkdenc-algo-1-hfrjq | step 458, loss = 0.0008808525162748992
# krfgwkdenc-algo-1-hfrjq | step 459, loss = 0.0009116649744100869
# krfgwkdenc-algo-1-hfrjq | step 460, loss = 0.0006185182719491422
# krfgwkdenc-algo-1-hfrjq | step 461, loss = 0.0007230506744235754
# krfgwkdenc-algo-1-hfrjq | step 462, loss = 0.0007475576130673289
# krfgwkdenc-algo-1-hfrjq | step 463, loss = 0.001227433793246746
# krfgwkdenc-algo-1-hfrjq | step 464, loss = 0.0013802158646285534
# krfgwkdenc-algo-1-hfrjq | step 465, loss = 0.000976044510025531
# krfgwkdenc-algo-1-hfrjq | step 466, loss = 0.00098913605324924
# krfgwkdenc-algo-1-hfrjq | step 467, loss = 0.0006348870228976011
# krfgwkdenc-algo-1-hfrjq | step 468, loss = 0.0010529145365580916
# krfgwkdenc-algo-1-hfrjq | step 469, loss = 0.0009345305152237415
# krfgwkdenc-algo-1-hfrjq | step 470, loss = 0.001188729191198945
# krfgwkdenc-algo-1-hfrjq | step 471, loss = 0.000880903797224164
# krfgwkdenc-algo-1-hfrjq | step 472, loss = 0.0011465216521173716
# krfgwkdenc-algo-1-hfrjq | step 473, loss = 0.0007767082424834371
# krfgwkdenc-algo-1-hfrjq | step 474, loss = 0.0007896546740084887
# krfgwkdenc-algo-1-hfrjq | step 475, loss = 0.0010461241472512484
# krfgwkdenc-algo-1-hfrjq | step 476, loss = 0.0009212968870997429
# krfgwkdenc-algo-1-hfrjq | step 477, loss = 0.0007693327497690916
# krfgwkdenc-algo-1-hfrjq | step 478, loss = 0.0008701308979652822
# krfgwkdenc-algo-1-hfrjq | step 479, loss = 0.001419633161276579
# krfgwkdenc-algo-1-hfrjq | step 480, loss = 0.0007640201947651803
# krfgwkdenc-algo-1-hfrjq | step 481, loss = 0.0011909810127690434
# krfgwkdenc-algo-1-hfrjq | step 482, loss = 0.000693685666192323
# krfgwkdenc-algo-1-hfrjq | step 483, loss = 0.0009929555235430598
# krfgwkdenc-algo-1-hfrjq | step 484, loss = 0.0005940443952567875
# krfgwkdenc-algo-1-hfrjq | step 485, loss = 0.0007404228090308607
# krfgwkdenc-algo-1-hfrjq | step 486, loss = 0.0008135387906804681
# krfgwkdenc-algo-1-hfrjq | step 487, loss = 0.0006848661578260362
# krfgwkdenc-algo-1-hfrjq | step 488, loss = 0.0005252099363133311
# krfgwkdenc-algo-1-hfrjq | step 489, loss = 0.0008256398141384125
# krfgwkdenc-algo-1-hfrjq | step 490, loss = 0.0008569674100726843
# krfgwkdenc-algo-1-hfrjq | step 491, loss = 0.0007240933482535183
# krfgwkdenc-algo-1-hfrjq | step 492, loss = 0.0007479184423573315
# krfgwkdenc-algo-1-hfrjq | step 493, loss = 0.00073320820229128
# krfgwkdenc-algo-1-hfrjq | step 494, loss = 0.0007416012231260538
# krfgwkdenc-algo-1-hfrjq | step 495, loss = 0.0006640709470957518
# krfgwkdenc-algo-1-hfrjq | step 496, loss = 0.0009956975700333714
# krfgwkdenc-algo-1-hfrjq | step 497, loss = 0.0008452192996628582
# krfgwkdenc-algo-1-hfrjq | step 498, loss = 0.0005818172357976437
# krfgwkdenc-algo-1-hfrjq | step 499, loss = 0.0005638516740873456
# krfgwkdenc-algo-1-hfrjq | step 500, loss = 0.00047908874694257975
# krfgwkdenc-algo-1-hfrjq | step 501, loss = 0.000871081545483321
# krfgwkdenc-algo-1-hfrjq | step 502, loss = 0.0008632113458588719
# krfgwkdenc-algo-1-hfrjq | step 503, loss = 0.0006091626128181815
# krfgwkdenc-algo-1-hfrjq | step 504, loss = 0.0006543057388626039
# krfgwkdenc-algo-1-hfrjq | step 505, loss = 0.0004894501180388033
# krfgwkdenc-algo-1-hfrjq | step 506, loss = 0.0006377542158588767
# krfgwkdenc-algo-1-hfrjq | step 507, loss = 0.0005167228518985212
# krfgwkdenc-algo-1-hfrjq | step 508, loss = 0.0006341107655316591
# krfgwkdenc-algo-1-hfrjq | step 509, loss = 0.0009707343997433782
# krfgwkdenc-algo-1-hfrjq | step 510, loss = 0.0007345448830164969
# krfgwkdenc-algo-1-hfrjq | step 511, loss = 0.0008308303076773882
# krfgwkdenc-algo-1-hfrjq | step 512, loss = 0.0007853266433812678
# krfgwkdenc-algo-1-hfrjq | step 513, loss = 0.0009977540466934443
# krfgwkdenc-algo-1-hfrjq | step 514, loss = 0.0005368416314013302
# krfgwkdenc-algo-1-hfrjq | step 515, loss = 0.0007764227339066565
# krfgwkdenc-algo-1-hfrjq | step 516, loss = 0.0007276387768797576
# krfgwkdenc-algo-1-hfrjq | step 517, loss = 0.000995828304439783
# krfgwkdenc-algo-1-hfrjq | step 518, loss = 0.0007690828060731292
# krfgwkdenc-algo-1-hfrjq | step 519, loss = 0.0005996132967993617
# krfgwkdenc-algo-1-hfrjq | step 520, loss = 0.0008235531277023256
# krfgwkdenc-algo-1-hfrjq | step 521, loss = 0.000775572785641998
# krfgwkdenc-algo-1-hfrjq | step 522, loss = 0.0009341499535366893
# krfgwkdenc-algo-1-hfrjq | step 523, loss = 0.0005527696339413524
# krfgwkdenc-algo-1-hfrjq | step 524, loss = 0.0006660367362201214
# krfgwkdenc-algo-1-hfrjq | step 525, loss = 0.0005040799733251333
# krfgwkdenc-algo-1-hfrjq | step 526, loss = 0.0006806572200730443
# krfgwkdenc-algo-1-hfrjq | step 527, loss = 0.0008652888354845345
# krfgwkdenc-algo-1-hfrjq | step 528, loss = 0.0007218486862257123
# krfgwkdenc-algo-1-hfrjq | step 529, loss = 0.00066907744621858
# krfgwkdenc-algo-1-hfrjq | step 530, loss = 0.0007011738489381969
# krfgwkdenc-algo-1-hfrjq | step 531, loss = 0.0008991816430352628
# krfgwkdenc-algo-1-hfrjq | step 532, loss = 0.0008813752792775631
# krfgwkdenc-algo-1-hfrjq | step 533, loss = 0.0007705693715251982
# krfgwkdenc-algo-1-hfrjq | step 534, loss = 0.0008330505806952715
# krfgwkdenc-algo-1-hfrjq | step 535, loss = 0.0008871427271515131
# krfgwkdenc-algo-1-hfrjq | step 536, loss = 0.0006171085988171399
# krfgwkdenc-algo-1-hfrjq | step 537, loss = 0.0005226230132393539
# krfgwkdenc-algo-1-hfrjq | step 538, loss = 0.0007624816498719156
# krfgwkdenc-algo-1-hfrjq | step 539, loss = 0.000638149562291801
# krfgwkdenc-algo-1-hfrjq | step 540, loss = 0.0005140195717103779
# krfgwkdenc-algo-1-hfrjq | step 541, loss = 0.0005145432660356164
# krfgwkdenc-algo-1-hfrjq | step 542, loss = 0.0005993345403112471
# krfgwkdenc-algo-1-hfrjq | step 543, loss = 0.0007717405096627772
# krfgwkdenc-algo-1-hfrjq | step 544, loss = 0.0005278205499053001
# krfgwkdenc-algo-1-hfrjq | step 545, loss = 0.0005592353409156203
# krfgwkdenc-algo-1-hfrjq | step 546, loss = 0.0004386582295410335
# krfgwkdenc-algo-1-hfrjq | step 547, loss = 0.0007197946542873979
# krfgwkdenc-algo-1-hfrjq | step 548, loss = 0.0005546590546146035
# krfgwkdenc-algo-1-hfrjq | step 549, loss = 0.0008189856307581067
# krfgwkdenc-algo-1-hfrjq | step 550, loss = 0.0007305452600121498
# krfgwkdenc-algo-1-hfrjq | step 551, loss = 0.0005905659054405987
# krfgwkdenc-algo-1-hfrjq | step 552, loss = 0.00036259330227039754
# krfgwkdenc-algo-1-hfrjq | step 553, loss = 0.0005937422974966466
# krfgwkdenc-algo-1-hfrjq | step 554, loss = 0.0006048526265658438
# krfgwkdenc-algo-1-hfrjq | step 555, loss = 0.0005347594851627946
# krfgwkdenc-algo-1-hfrjq | step 556, loss = 0.0005191572126932442
# krfgwkdenc-algo-1-hfrjq | step 557, loss = 0.0007328317733481526
# krfgwkdenc-algo-1-hfrjq | step 558, loss = 0.00043223038665018976
# krfgwkdenc-algo-1-hfrjq | step 559, loss = 0.0006680055521428585
# krfgwkdenc-algo-1-hfrjq | step 560, loss = 0.0007113654864951968
# krfgwkdenc-algo-1-hfrjq | step 561, loss = 0.0007246547029353678
# krfgwkdenc-algo-1-hfrjq | step 562, loss = 0.0005062350537627935
# krfgwkdenc-algo-1-hfrjq | step 563, loss = 0.0004348387010395527
# krfgwkdenc-algo-1-hfrjq | step 564, loss = 0.0005633472464978695
# krfgwkdenc-algo-1-hfrjq | step 565, loss = 0.0008409437141381204
# krfgwkdenc-algo-1-hfrjq | step 566, loss = 0.0006634042947553098
# krfgwkdenc-algo-1-hfrjq | step 567, loss = 0.0008367377449758351
# krfgwkdenc-algo-1-hfrjq | step 568, loss = 0.0003794053045567125
# krfgwkdenc-algo-1-hfrjq | step 569, loss = 0.0006819198606535792
# krfgwkdenc-algo-1-hfrjq | step 570, loss = 0.0007032918510958552
# krfgwkdenc-algo-1-hfrjq | step 571, loss = 0.0005393272149376571
# krfgwkdenc-algo-1-hfrjq | step 572, loss = 0.00039936319808475673
# krfgwkdenc-algo-1-hfrjq | step 573, loss = 0.0008827362908050418
# krfgwkdenc-algo-1-hfrjq | step 574, loss = 0.0008003836264833808
# krfgwkdenc-algo-1-hfrjq | step 575, loss = 0.0004239293048158288
# krfgwkdenc-algo-1-hfrjq | step 576, loss = 0.0006742542027495801
# krfgwkdenc-algo-1-hfrjq | step 577, loss = 0.000717182585503906
# krfgwkdenc-algo-1-hfrjq | step 578, loss = 0.0007011163979768753
# krfgwkdenc-algo-1-hfrjq | step 579, loss = 0.0004629956092685461
# krfgwkdenc-algo-1-hfrjq | step 580, loss = 0.00045733313891105354
# krfgwkdenc-algo-1-hfrjq | step 581, loss = 0.0008804667158983648
# krfgwkdenc-algo-1-hfrjq | step 582, loss = 0.0006714700139127672
# krfgwkdenc-algo-1-hfrjq | step 583, loss = 0.0006506374920718372
# krfgwkdenc-algo-1-hfrjq | step 584, loss = 0.0007623450946994126
# krfgwkdenc-algo-1-hfrjq | step 585, loss = 0.0007103747338987887
# krfgwkdenc-algo-1-hfrjq | step 586, loss = 0.0007357588619925082
# krfgwkdenc-algo-1-hfrjq | step 587, loss = 0.0005305754020810127
# krfgwkdenc-algo-1-hfrjq | step 588, loss = 0.00046601364738307893
# krfgwkdenc-algo-1-hfrjq | step 589, loss = 0.000542780093383044
# krfgwkdenc-algo-1-hfrjq | step 590, loss = 0.00032350936089642346
# krfgwkdenc-algo-1-hfrjq | step 591, loss = 0.0004338014405220747
# krfgwkdenc-algo-1-hfrjq | step 592, loss = 0.0006385584129020572
# krfgwkdenc-algo-1-hfrjq | step 593, loss = 0.000676563533488661
# krfgwkdenc-algo-1-hfrjq | step 594, loss = 0.0005271168774925172
# krfgwkdenc-algo-1-hfrjq | step 595, loss = 0.0007260763086378574
# krfgwkdenc-algo-1-hfrjq | step 596, loss = 0.0006465534097515047
# krfgwkdenc-algo-1-hfrjq | step 597, loss = 0.0004403300990816206
# krfgwkdenc-algo-1-hfrjq | step 598, loss = 0.0005441876128315926
# krfgwkdenc-algo-1-hfrjq | step 599, loss = 0.00045602762838825583
# krfgwkdenc-algo-1-hfrjq | step 600, loss = 0.0005195785779505968
# krfgwkdenc-algo-1-hfrjq | step 601, loss = 0.0005770287825725973
# krfgwkdenc-algo-1-hfrjq | step 602, loss = 0.00039691009442321956
# krfgwkdenc-algo-1-hfrjq | step 603, loss = 0.0006017428822815418
# krfgwkdenc-algo-1-hfrjq | step 604, loss = 0.0006523191113956273
# krfgwkdenc-algo-1-hfrjq | step 605, loss = 0.0003766543813981116
# krfgwkdenc-algo-1-hfrjq | step 606, loss = 0.00043036526767537
# krfgwkdenc-algo-1-hfrjq | step 607, loss = 0.0005469487514346838
# krfgwkdenc-algo-1-hfrjq | step 608, loss = 0.0007160904933698475
# krfgwkdenc-algo-1-hfrjq | step 609, loss = 0.0003480230807326734
# krfgwkdenc-algo-1-hfrjq | step 610, loss = 0.0007130250451155007
# krfgwkdenc-algo-1-hfrjq | step 611, loss = 0.0007047667168080807
# krfgwkdenc-algo-1-hfrjq | step 612, loss = 0.0006690893787890673
# krfgwkdenc-algo-1-hfrjq | step 613, loss = 0.0005630786763504148
# krfgwkdenc-algo-1-hfrjq | step 614, loss = 0.00031962463981471956
# krfgwkdenc-algo-1-hfrjq | step 615, loss = 0.0004600686952471733
# krfgwkdenc-algo-1-hfrjq | step 616, loss = 0.0005475502111949027
# krfgwkdenc-algo-1-hfrjq | step 617, loss = 0.00037431303644552827
# krfgwkdenc-algo-1-hfrjq | step 618, loss = 0.00047694097156636417
# krfgwkdenc-algo-1-hfrjq | step 619, loss = 0.00037782726576551795
# krfgwkdenc-algo-1-hfrjq | step 620, loss = 0.00042226709774695337
# krfgwkdenc-algo-1-hfrjq | step 621, loss = 0.0007169340969994664
# krfgwkdenc-algo-1-hfrjq | step 622, loss = 0.0007684638840146363
# krfgwkdenc-algo-1-hfrjq | step 623, loss = 0.0004895895253866911
# krfgwkdenc-algo-1-hfrjq | step 624, loss = 0.0005131748039275408
# krfgwkdenc-algo-1-hfrjq | step 625, loss = 0.00045095974928699434
# krfgwkdenc-algo-1-hfrjq | step 626, loss = 0.0005599757423624396
# krfgwkdenc-algo-1-hfrjq | step 627, loss = 0.0008844340336509049
# krfgwkdenc-algo-1-hfrjq | step 628, loss = 0.0005457269726321101
# krfgwkdenc-algo-1-hfrjq | step 629, loss = 0.00042176322313025594
# krfgwkdenc-algo-1-hfrjq | step 630, loss = 0.0006225971155799925
# krfgwkdenc-algo-1-hfrjq | step 631, loss = 0.0004909071139991283
# krfgwkdenc-algo-1-hfrjq | step 632, loss = 0.0005174021353013813
# krfgwkdenc-algo-1-hfrjq | step 633, loss = 0.0005579635035246611
# krfgwkdenc-algo-1-hfrjq | step 634, loss = 0.0007273683440871537
# krfgwkdenc-algo-1-hfrjq | step 635, loss = 0.000656892079859972
# krfgwkdenc-algo-1-hfrjq | step 636, loss = 0.0004731296212412417
# krfgwkdenc-algo-1-hfrjq | step 637, loss = 0.0006164992810226977
# krfgwkdenc-algo-1-hfrjq | step 638, loss = 0.0005217420984990895
# krfgwkdenc-algo-1-hfrjq | step 639, loss = 0.00036493223160505295
# krfgwkdenc-algo-1-hfrjq | step 640, loss = 0.00044776956201530993
# krfgwkdenc-algo-1-hfrjq | step 641, loss = 0.000406326464144513
# krfgwkdenc-algo-1-hfrjq | step 642, loss = 0.0005619253497570753
# krfgwkdenc-algo-1-hfrjq | step 643, loss = 0.00046487103099934757
# krfgwkdenc-algo-1-hfrjq | step 644, loss = 0.0006828726618550718
# krfgwkdenc-algo-1-hfrjq | step 645, loss = 0.0006548633682541549
# krfgwkdenc-algo-1-hfrjq | step 646, loss = 0.0005829471629112959
# krfgwkdenc-algo-1-hfrjq | step 647, loss = 0.0004884981899522245
# krfgwkdenc-algo-1-hfrjq | step 648, loss = 0.0004331638338044286
# krfgwkdenc-algo-1-hfrjq | step 649, loss = 0.0003301592660136521
# krfgwkdenc-algo-1-hfrjq | step 650, loss = 0.00039637493318878114
# krfgwkdenc-algo-1-hfrjq | step 651, loss = 0.000586542475502938
# krfgwkdenc-algo-1-hfrjq | step 652, loss = 0.000639156496617943
# krfgwkdenc-algo-1-hfrjq | step 653, loss = 0.000671158020850271
# krfgwkdenc-algo-1-hfrjq | step 654, loss = 0.0006295723142102361
# krfgwkdenc-algo-1-hfrjq | step 655, loss = 0.0005917235976085067
# krfgwkdenc-algo-1-hfrjq | step 656, loss = 0.000600164697971195
# krfgwkdenc-algo-1-hfrjq | step 657, loss = 0.00029387365793809295
# krfgwkdenc-algo-1-hfrjq | step 658, loss = 0.0005097916582599282
# krfgwkdenc-algo-1-hfrjq | step 659, loss = 0.000547971052583307
# krfgwkdenc-algo-1-hfrjq | step 660, loss = 0.0005883041303604841
# krfgwkdenc-algo-1-hfrjq | step 661, loss = 0.00033723143860697746
# krfgwkdenc-algo-1-hfrjq | step 662, loss = 0.000546495895832777
# krfgwkdenc-algo-1-hfrjq | step 663, loss = 0.0004608235612977296
# krfgwkdenc-algo-1-hfrjq | step 664, loss = 0.0004391422844491899
# krfgwkdenc-algo-1-hfrjq | step 665, loss = 0.0006660498911514878
# krfgwkdenc-algo-1-hfrjq | step 666, loss = 0.0003470515366643667
# krfgwkdenc-algo-1-hfrjq | step 667, loss = 0.0004924840177409351
# krfgwkdenc-algo-1-hfrjq | step 668, loss = 0.0004726967599708587
# krfgwkdenc-algo-1-hfrjq | step 669, loss = 0.0005264990613795817
# krfgwkdenc-algo-1-hfrjq | step 670, loss = 0.00033304240787401795
# krfgwkdenc-algo-1-hfrjq | step 671, loss = 0.0004591594624798745
# krfgwkdenc-algo-1-hfrjq | step 672, loss = 0.0007384510827250779
# krfgwkdenc-algo-1-hfrjq | step 673, loss = 0.0004513012245297432
# krfgwkdenc-algo-1-hfrjq | step 674, loss = 0.0005910120671615005
# krfgwkdenc-algo-1-hfrjq | step 675, loss = 0.000419286428950727
# krfgwkdenc-algo-1-hfrjq | step 676, loss = 0.0003861871955450624
# krfgwkdenc-algo-1-hfrjq | step 677, loss = 0.0003892440290655941
# krfgwkdenc-algo-1-hfrjq | step 678, loss = 0.0008076188969425857
# krfgwkdenc-algo-1-hfrjq | step 679, loss = 0.0006178789772093296
# krfgwkdenc-algo-1-hfrjq | step 680, loss = 0.0003150985576212406
# krfgwkdenc-algo-1-hfrjq | step 681, loss = 0.0004642486746888608
# krfgwkdenc-algo-1-hfrjq | step 682, loss = 0.00043758528772741556
# krfgwkdenc-algo-1-hfrjq | step 683, loss = 0.0004840334877371788
# krfgwkdenc-algo-1-hfrjq | step 684, loss = 0.0003582867211662233
# krfgwkdenc-algo-1-hfrjq | step 685, loss = 0.0005840124213136733
# krfgwkdenc-algo-1-hfrjq | step 686, loss = 0.00035356139414943755
# krfgwkdenc-algo-1-hfrjq | step 687, loss = 0.0005308886175043881
# krfgwkdenc-algo-1-hfrjq | step 688, loss = 0.00035639689303934574
# krfgwkdenc-algo-1-hfrjq | step 689, loss = 0.0005556673859246075
# krfgwkdenc-algo-1-hfrjq | step 690, loss = 0.0005837882054038346
# krfgwkdenc-algo-1-hfrjq | step 691, loss = 0.0005396458436734974
# krfgwkdenc-algo-1-hfrjq | step 692, loss = 0.0005960772396065295
# krfgwkdenc-algo-1-hfrjq | step 693, loss = 0.0005912667256779969
# krfgwkdenc-algo-1-hfrjq | step 694, loss = 0.0005749007104896009
# krfgwkdenc-algo-1-hfrjq | step 695, loss = 0.0005070897750556469
# krfgwkdenc-algo-1-hfrjq | step 696, loss = 0.0005913705099374056
# krfgwkdenc-algo-1-hfrjq | step 697, loss = 0.00047001472557894886
# krfgwkdenc-algo-1-hfrjq | step 698, loss = 0.0003409127239137888
# krfgwkdenc-algo-1-hfrjq | step 699, loss = 0.0002643426414579153
# krfgwkdenc-algo-1-hfrjq | step 700, loss = 0.00047678538248874247
# krfgwkdenc-algo-1-hfrjq | step 701, loss = 0.00025811936939135194
# krfgwkdenc-algo-1-hfrjq | step 702, loss = 0.00035996484803035855
# krfgwkdenc-algo-1-hfrjq | step 703, loss = 0.0004933814634568989
# krfgwkdenc-algo-1-hfrjq | step 704, loss = 0.00038469498394988477
# krfgwkdenc-algo-1-hfrjq | step 705, loss = 0.0005022145924158394
# krfgwkdenc-algo-1-hfrjq | step 706, loss = 0.000446982157882303
# krfgwkdenc-algo-1-hfrjq | step 707, loss = 0.0006484739133156836
# krfgwkdenc-algo-1-hfrjq | step 708, loss = 0.0006987201632000506
# krfgwkdenc-algo-1-hfrjq | step 709, loss = 0.0003260626981500536
# krfgwkdenc-algo-1-hfrjq | step 710, loss = 0.0005653493572026491
# krfgwkdenc-algo-1-hfrjq | step 711, loss = 0.0005650207167491317
# krfgwkdenc-algo-1-hfrjq | step 712, loss = 0.00045243086060509086
# krfgwkdenc-algo-1-hfrjq | step 713, loss = 0.0005522994906641543
# krfgwkdenc-algo-1-hfrjq | step 714, loss = 0.0003341311530675739
# krfgwkdenc-algo-1-hfrjq | step 715, loss = 0.000740972172934562
# krfgwkdenc-algo-1-hfrjq | step 716, loss = 0.00032576872035861015
# krfgwkdenc-algo-1-hfrjq | step 717, loss = 0.0004438891483005136
# ...
# krfgwkdenc-algo-1-hfrjq | step 758, loss = 0.00044914832687936723
# krfgwkdenc-algo-1-hfrjq | step 759, loss = 0.0005586957558989525
# krfgwkdenc-algo-1-hfrjq | step 760, loss = 0.0005155627732165158
# krfgwkdenc-algo-1-hfrjq | step 761, loss = 0.0004853703430853784
# krfgwkdenc-algo-1-hfrjq | step 762, loss = 0.0005416427738964558
# krfgwkdenc-algo-1-hfrjq | step 763, loss = 0.0005397707573138177
# krfgwkdenc-algo-1-hfrjq | step 764, loss = 0.000445035460870713
# krfgwkdenc-algo-1-hfrjq | step 765, loss = 0.0004944762913510203
# krfgwkdenc-algo-1-hfrjq | step 766, loss = 0.000440498988609761
# krfgwkdenc-algo-1-hfrjq | step 767, loss = 0.0003921460884157568
# krfgwkdenc-algo-1-hfrjq | step 768, loss = 0.00046665535774081945
# krfgwkdenc-algo-1-hfrjq | step 769, loss = 0.0004957413766533136
# krfgwkdenc-algo-1-hfrjq | step 770, loss = 0.0005513153737410903
# krfgwkdenc-algo-1-hfrjq | step 771, loss = 0.0006157616735436022
# krfgwkdenc-algo-1-hfrjq | step 772, loss = 0.0003569849650375545
# krfgwkdenc-algo-1-hfrjq | step 773, loss = 0.00027890605269931257
# krfgwkdenc-algo-1-hfrjq | step 774, loss = 0.0004812119295820594
# krfgwkdenc-algo-1-hfrjq | step 775, loss = 0.0003808189067058265
# krfgwkdenc-algo-1-hfrjq | step 776, loss = 0.0004336572892498225
# krfgwkdenc-algo-1-hfrjq | step 777, loss = 0.00039378562360070646
# krfgwkdenc-algo-1-hfrjq | step 778, loss = 0.00031198252690955997
# krfgwkdenc-algo-1-hfrjq | step 779, loss = 0.0004535447806119919
# krfgwkdenc-algo-1-hfrjq | step 780, loss = 0.0003493276017252356
# krfgwkdenc-algo-1-hfrjq | step 781, loss = 0.00033078063279390335
# krfgwkdenc-algo-1-hfrjq | step 782, loss = 0.0003798360994551331
# krfgwkdenc-algo-1-hfrjq | step 783, loss = 0.00045351398875936866
# krfgwkdenc-algo-1-hfrjq | step 784, loss = 0.000425602775067091
# krfgwkdenc-algo-1-hfrjq | step 785, loss = 0.0004568498698063195
# krfgwkdenc-algo-1-hfrjq | step 786, loss = 0.0005087095778435469
# krfgwkdenc-algo-1-hfrjq | step 787, loss = 0.0004820717149414122
# krfgwkdenc-algo-1-hfrjq | step 788, loss = 0.00031259775278158486
# krfgwkdenc-algo-1-hfrjq | step 789, loss = 0.00036498953704722226
# krfgwkdenc-algo-1-hfrjq | step 790, loss = 0.0005389181314967573
# krfgwkdenc-algo-1-hfrjq | step 791, loss = 0.0005818191566504538
# krfgwkdenc-algo-1-hfrjq | step 792, loss = 0.0003270109591539949
# krfgwkdenc-algo-1-hfrjq | step 793, loss = 0.00044776342110708356
# krfgwkdenc-algo-1-hfrjq | step 794, loss = 0.0005364285316318274
# krfgwkdenc-algo-1-hfrjq | step 795, loss = 0.0004695744428317994
# krfgwkdenc-algo-1-hfrjq | step 796, loss = 0.00047023335355333984
# krfgwkdenc-algo-1-hfrjq | step 797, loss = 0.00031627569114789367
# krfgwkdenc-algo-1-hfrjq | step 798, loss = 0.0006620964268222451
# krfgwkdenc-algo-1-hfrjq | step 799, loss = 0.0005356106557883322
# krfgwkdenc-algo-1-hfrjq | step 800, loss = 0.00041958779911510646
# krfgwkdenc-algo-1-hfrjq | step 801, loss = 0.0003680795489344746
# krfgwkdenc-algo-1-hfrjq | step 802, loss = 0.0003819634730461985
# krfgwkdenc-algo-1-hfrjq | step 803, loss = 0.00039468929753638804
# krfgwkdenc-algo-1-hfrjq | step 804, loss = 0.0003824847808573395
# krfgwkdenc-algo-1-hfrjq | step 805, loss = 0.0002872477925848216
# krfgwkdenc-algo-1-hfrjq | step 806, loss = 0.00029378916951827705
# krfgwkdenc-algo-1-hfrjq | step 807, loss = 0.00037042994517832994
# krfgwkdenc-algo-1-hfrjq | step 808, loss = 0.00036129611544311047
# krfgwkdenc-algo-1-hfrjq | step 809, loss = 0.00034630301524885
# krfgwkdenc-algo-1-hfrjq | step 810, loss = 0.000517842941917479
# krfgwkdenc-algo-1-hfrjq | step 811, loss = 0.00033923261798918247
# krfgwkdenc-algo-1-hfrjq | step 812, loss = 0.0003365569864399731
# krfgwkdenc-algo-1-hfrjq | step 813, loss = 0.0005228567752055824
# krfgwkdenc-algo-1-hfrjq | step 814, loss = 0.00039030765765346587
# krfgwkdenc-algo-1-hfrjq | step 815, loss = 0.00047590702888555825
# krfgwkdenc-algo-1-hfrjq | step 816, loss = 0.000488497200421989
# krfgwkdenc-algo-1-hfrjq | step 817, loss = 0.0004781079769600183
# krfgwkdenc-algo-1-hfrjq | step 818, loss = 0.0005218436126597226
# krfgwkdenc-algo-1-hfrjq | step 819, loss = 0.00045960425632074475
# krfgwkdenc-algo-1-hfrjq | step 820, loss = 0.0004710363282356411
# krfgwkdenc-algo-1-hfrjq | step 821, loss = 0.00037573155714198947
# krfgwkdenc-algo-1-hfrjq | step 822, loss = 0.0003190321149304509
# krfgwkdenc-algo-1-hfrjq | step 823, loss = 0.00042488143662922084
# krfgwkdenc-algo-1-hfrjq | step 824, loss = 0.0003760770196095109
# krfgwkdenc-algo-1-hfrjq | step 825, loss = 0.0003990436380263418
# krfgwkdenc-algo-1-hfrjq | step 826, loss = 0.0005548261106014252
# krfgwkdenc-algo-1-hfrjq | step 827, loss = 0.00041759596206247807
# krfgwkdenc-algo-1-hfrjq | step 828, loss = 0.0006881660665385425
# krfgwkdenc-algo-1-hfrjq | step 829, loss = 0.00036774761974811554
# krfgwkdenc-algo-1-hfrjq | step 830, loss = 0.0004467481339816004
# krfgwkdenc-algo-1-hfrjq | step 831, loss = 0.00036369377630762756
# krfgwkdenc-algo-1-hfrjq | step 832, loss = 0.0004494220484048128
# krfgwkdenc-algo-1-hfrjq | step 833, loss = 0.0006609368720091879
# krfgwkdenc-algo-1-hfrjq | step 834, loss = 0.0003495195705909282
# krfgwkdenc-algo-1-hfrjq | step 835, loss = 0.0004466019745450467
# krfgwkdenc-algo-1-hfrjq | step 836, loss = 0.000412014895118773
# krfgwkdenc-algo-1-hfrjq | step 837, loss = 0.00028688192833215
# krfgwkdenc-algo-1-hfrjq | step 838, loss = 0.00043413203093223274
# krfgwkdenc-algo-1-hfrjq | step 839, loss = 0.00032769012614153326
# krfgwkdenc-algo-1-hfrjq | step 840, loss = 0.00046851695515215397
# krfgwkdenc-algo-1-hfrjq | step 841, loss = 0.0003643047821242362
# krfgwkdenc-algo-1-hfrjq | step 842, loss = 0.000424682890297845
# krfgwkdenc-algo-1-hfrjq | step 843, loss = 0.00034004737972281873
# krfgwkdenc-algo-1-hfrjq | step 844, loss = 0.00035163440043106675
# krfgwkdenc-algo-1-hfrjq | step 845, loss = 0.00028668594313785434
# krfgwkdenc-algo-1-hfrjq | step 846, loss = 0.0002781459188554436
# krfgwkdenc-algo-1-hfrjq | step 847, loss = 0.00041962880641222
# krfgwkdenc-algo-1-hfrjq | step 848, loss = 0.000436026428360492
# krfgwkdenc-algo-1-hfrjq | step 849, loss = 0.0003811124188359827
# krfgwkdenc-algo-1-hfrjq | step 850, loss = 0.00035593166830949485
# krfgwkdenc-algo-1-hfrjq | step 851, loss = 0.00045597049756906927
# krfgwkdenc-algo-1-hfrjq | step 852, loss = 0.0003391326463315636
# krfgwkdenc-algo-1-hfrjq | step 853, loss = 0.0003493510012049228
# krfgwkdenc-algo-1-hfrjq | step 854, loss = 0.0005218064761720598
# krfgwkdenc-algo-1-hfrjq | step 855, loss = 0.00035768651287071407
# krfgwkdenc-algo-1-hfrjq | step 856, loss = 0.0005995732499286532
# krfgwkdenc-algo-1-hfrjq | step 857, loss = 0.0003092636470682919
# krfgwkdenc-algo-1-hfrjq | step 858, loss = 0.00045150367077440023
# krfgwkdenc-algo-1-hfrjq | step 859, loss = 0.0003851235087495297
# krfgwkdenc-algo-1-hfrjq | step 860, loss = 0.0003481966850813478
# krfgwkdenc-algo-1-hfrjq | step 861, loss = 0.0004026842361781746
# krfgwkdenc-algo-1-hfrjq | step 862, loss = 0.0004535871557891369
# krfgwkdenc-algo-1-hfrjq | step 863, loss = 0.0002950625494122505
# krfgwkdenc-algo-1-hfrjq | step 864, loss = 0.00033653114223852754
# krfgwkdenc-algo-1-hfrjq | step 865, loss = 0.0003360782575327903
# krfgwkdenc-algo-1-hfrjq | step 866, loss = 0.00042151095112785697
# krfgwkdenc-algo-1-hfrjq | step 867, loss = 0.0005357508780434728
# krfgwkdenc-algo-1-hfrjq | step 868, loss = 0.00047369004460051656
# krfgwkdenc-algo-1-hfrjq | step 869, loss = 0.000401689758291468
# krfgwkdenc-algo-1-hfrjq | step 870, loss = 0.00043735402869060636
# krfgwkdenc-algo-1-hfrjq | step 871, loss = 0.0003624001983553171
# krfgwkdenc-algo-1-hfrjq | step 872, loss = 0.00040643318789079785
# krfgwkdenc-algo-1-hfrjq | step 873, loss = 0.0005001217941753566
# krfgwkdenc-algo-1-hfrjq | step 874, loss = 0.00039883676799945533
# krfgwkdenc-algo-1-hfrjq | step 875, loss = 0.00028020390891470015
# krfgwkdenc-algo-1-hfrjq | step 876, loss = 0.0003911372332368046
# krfgwkdenc-algo-1-hfrjq | step 877, loss = 0.00032556551741436124
# krfgwkdenc-algo-1-hfrjq | step 878, loss = 0.00038034477620385587
# krfgwkdenc-algo-1-hfrjq | step 879, loss = 0.0004861220659222454
# krfgwkdenc-algo-1-hfrjq | step 880, loss = 0.0003914370608981699
# krfgwkdenc-algo-1-hfrjq | step 881, loss = 0.0003492199466563761
# krfgwkdenc-algo-1-hfrjq | step 882, loss = 0.00037912107654847205
# krfgwkdenc-algo-1-hfrjq | step 883, loss = 0.0002949331246782094
# krfgwkdenc-algo-1-hfrjq | step 884, loss = 0.0003075731510762125
# krfgwkdenc-algo-1-hfrjq | step 885, loss = 0.00045738060725852847
# krfgwkdenc-algo-1-hfrjq | step 886, loss = 0.00046377480612136424
# krfgwkdenc-algo-1-hfrjq | step 887, loss = 0.0003041270829271525
# krfgwkdenc-algo-1-hfrjq | step 888, loss = 0.00035984301939606667
# krfgwkdenc-algo-1-hfrjq | step 889, loss = 0.00036691571585834026
# krfgwkdenc-algo-1-hfrjq | step 890, loss = 0.0003492979158181697
# krfgwkdenc-algo-1-hfrjq | step 891, loss = 0.0003653486492112279
# krfgwkdenc-algo-1-hfrjq | step 892, loss = 0.0004984676488675177
# krfgwkdenc-algo-1-hfrjq | step 893, loss = 0.0003342523123137653
# krfgwkdenc-algo-1-hfrjq | step 894, loss = 0.0003566943923942745
# krfgwkdenc-algo-1-hfrjq | step 895, loss = 0.00039777375059202313
# krfgwkdenc-algo-1-hfrjq | step 896, loss = 0.00041109960875473917
# krfgwkdenc-algo-1-hfrjq | step 897, loss = 0.0002959846460726112
# krfgwkdenc-algo-1-hfrjq | step 898, loss = 0.00043467292562127113
# krfgwkdenc-algo-1-hfrjq | step 899, loss = 0.00030153716215863824
# krfgwkdenc-algo-1-hfrjq | step 900, loss = 0.0005297938478179276
# krfgwkdenc-algo-1-hfrjq | step 901, loss = 0.00034716888330876827
# krfgwkdenc-algo-1-hfrjq | step 902, loss = 0.00029858495690859854
# krfgwkdenc-algo-1-hfrjq | step 903, loss = 0.0004118556680623442
# krfgwkdenc-algo-1-hfrjq | step 904, loss = 0.0003099169407505542
# krfgwkdenc-algo-1-hfrjq | step 905, loss = 0.0004291587683837861
# krfgwkdenc-algo-1-hfrjq | step 906, loss = 0.0003115605213679373
# krfgwkdenc-algo-1-hfrjq | step 907, loss = 0.00038865109672769904
# krfgwkdenc-algo-1-hfrjq | step 908, loss = 0.0003847658808808774
# krfgwkdenc-algo-1-hfrjq | step 909, loss = 0.0002852560137398541
# krfgwkdenc-algo-1-hfrjq | step 910, loss = 0.00037301486008800566
# krfgwkdenc-algo-1-hfrjq | step 911, loss = 0.00040454394184052944
# krfgwkdenc-algo-1-hfrjq | step 912, loss = 0.0003208821581210941
# krfgwkdenc-algo-1-hfrjq | step 913, loss = 0.0005137747502885759
# krfgwkdenc-algo-1-hfrjq | step 914, loss = 0.00033151349634863436
# krfgwkdenc-algo-1-hfrjq | step 915, loss = 0.00038647869951091707
# krfgwkdenc-algo-1-hfrjq | step 916, loss = 0.0005600144504569471
# krfgwkdenc-algo-1-hfrjq | step 917, loss = 0.00035300033050589263
# krfgwkdenc-algo-1-hfrjq | step 918, loss = 0.0003611495776567608
# krfgwkdenc-algo-1-hfrjq | step 919, loss = 0.00042057668906636536
# krfgwkdenc-algo-1-hfrjq | step 920, loss = 0.0003455879632383585
# krfgwkdenc-algo-1-hfrjq | step 921, loss = 0.0003557036689016968
# krfgwkdenc-algo-1-hfrjq | step 922, loss = 0.000292679644189775
# krfgwkdenc-algo-1-hfrjq | step 923, loss = 0.00040166385588236153
# krfgwkdenc-algo-1-hfrjq | step 924, loss = 0.0003711350727826357
# krfgwkdenc-algo-1-hfrjq | step 925, loss = 0.0003889156796503812
# krfgwkdenc-algo-1-hfrjq | step 926, loss = 0.00030520971631631255
# krfgwkdenc-algo-1-hfrjq | step 927, loss = 0.00036469363840296865
# krfgwkdenc-algo-1-hfrjq | step 928, loss = 0.00047192187048494816
# krfgwkdenc-algo-1-hfrjq | step 929, loss = 0.0004067491099704057
# krfgwkdenc-algo-1-hfrjq | step 930, loss = 0.00023297141888178885
# krfgwkdenc-algo-1-hfrjq | step 931, loss = 0.00040073611307889223
# krfgwkdenc-algo-1-hfrjq | step 932, loss = 0.0002986810286529362
# krfgwkdenc-algo-1-hfrjq | step 933, loss = 0.0003583391080610454
# krfgwkdenc-algo-1-hfrjq | step 934, loss = 0.0004454441659618169
# krfgwkdenc-algo-1-hfrjq | step 935, loss = 0.0005059452960267663
# krfgwkdenc-algo-1-hfrjq | step 936, loss = 0.0003585995582398027
# krfgwkdenc-algo-1-hfrjq | step 937, loss = 0.00033660538611002266
# krfgwkdenc-algo-1-hfrjq | step 938, loss = 0.0003354258369654417
# krfgwkdenc-algo-1-hfrjq | step 939, loss = 0.0003016665286850184
# krfgwkdenc-algo-1-hfrjq | step 940, loss = 0.00043958795140497386
# krfgwkdenc-algo-1-hfrjq | step 941, loss = 0.00023934105411171913
# krfgwkdenc-algo-1-hfrjq | step 942, loss = 0.00020587019389495254
# krfgwkdenc-algo-1-hfrjq | step 943, loss = 0.0003871198568958789
# krfgwkdenc-algo-1-hfrjq | step 944, loss = 0.00028431008104234934
# krfgwkdenc-algo-1-hfrjq | step 945, loss = 0.0004221245471853763
# krfgwkdenc-algo-1-hfrjq | step 946, loss = 0.0003540374164003879
# krfgwkdenc-algo-1-hfrjq | step 947, loss = 0.00035260291770100594
# krfgwkdenc-algo-1-hfrjq | step 948, loss = 0.00038009838317520916
# krfgwkdenc-algo-1-hfrjq | step 949, loss = 0.0003410762292332947
# krfgwkdenc-algo-1-hfrjq | step 950, loss = 0.0002592834644019604
# krfgwkdenc-algo-1-hfrjq | step 951, loss = 0.0003070560051128268
# krfgwkdenc-algo-1-hfrjq | step 952, loss = 0.0005032659973949194
# krfgwkdenc-algo-1-hfrjq | step 953, loss = 0.0003085603821091354
# krfgwkdenc-algo-1-hfrjq | step 954, loss = 0.0003658585192169994
# krfgwkdenc-algo-1-hfrjq | step 955, loss = 0.00045172468526288867
# krfgwkdenc-algo-1-hfrjq | step 956, loss = 0.00032255565747618675
# krfgwkdenc-algo-1-hfrjq | step 957, loss = 0.0003623408265411854
# krfgwkdenc-algo-1-hfrjq | step 958, loss = 0.0003727510920725763
# krfgwkdenc-algo-1-hfrjq | step 959, loss = 0.00032792732235975564
# krfgwkdenc-algo-1-hfrjq | step 960, loss = 0.0003148198884446174
# krfgwkdenc-algo-1-hfrjq | step 961, loss = 0.0004466791870072484
# krfgwkdenc-algo-1-hfrjq | step 962, loss = 0.0003814607916865498
# krfgwkdenc-algo-1-hfrjq | step 963, loss = 0.000385505729354918
# krfgwkdenc-algo-1-hfrjq | step 964, loss = 0.0003876622940879315
# krfgwkdenc-algo-1-hfrjq | step 965, loss = 0.00030786002753302455
# krfgwkdenc-algo-1-hfrjq | step 966, loss = 0.00035523029509931803
# krfgwkdenc-algo-1-hfrjq | step 967, loss = 0.00033842463744804263
# krfgwkdenc-algo-1-hfrjq | step 968, loss = 0.0003003132587764412
# krfgwkdenc-algo-1-hfrjq | step 969, loss = 0.0003738325322046876
# krfgwkdenc-algo-1-hfrjq | step 970, loss = 0.00032192509388551116
# krfgwkdenc-algo-1-hfrjq | step 971, loss = 0.00038454000605270267
# krfgwkdenc-algo-1-hfrjq | step 972, loss = 0.000356202304828912
# krfgwkdenc-algo-1-hfrjq | step 973, loss = 0.0003160733904223889
# krfgwkdenc-algo-1-hfrjq | step 974, loss = 0.0003664235700853169
# krfgwkdenc-algo-1-hfrjq | step 975, loss = 0.00042139639845117927
# krfgwkdenc-algo-1-hfrjq | step 976, loss = 0.0003958721936214715
# krfgwkdenc-algo-1-hfrjq | step 977, loss = 0.0003824387677013874
# krfgwkdenc-algo-1-hfrjq | step 978, loss = 0.00042256421875208616
# krfgwkdenc-algo-1-hfrjq | step 979, loss = 0.0003652485611382872
# krfgwkdenc-algo-1-hfrjq | step 980, loss = 0.0003300925309304148
# krfgwkdenc-algo-1-hfrjq | step 981, loss = 0.0005288472166284919
# krfgwkdenc-algo-1-hfrjq | step 982, loss = 0.0004065629909746349
# krfgwkdenc-algo-1-hfrjq | step 983, loss = 0.0003692755999509245
# krfgwkdenc-algo-1-hfrjq | step 984, loss = 0.00035188463516533375
# krfgwkdenc-algo-1-hfrjq | step 985, loss = 0.0002704794460441917
# krfgwkdenc-algo-1-hfrjq | step 986, loss = 0.00031927088275551796
# krfgwkdenc-algo-1-hfrjq | step 987, loss = 0.0003155974845867604
# krfgwkdenc-algo-1-hfrjq | step 988, loss = 0.0003124343929812312
# krfgwkdenc-algo-1-hfrjq | step 989, loss = 0.0002627616631798446
# krfgwkdenc-algo-1-hfrjq | step 990, loss = 0.000247503281570971
# krfgwkdenc-algo-1-hfrjq | step 991, loss = 0.0002565124596003443
# krfgwkdenc-algo-1-hfrjq | step 992, loss = 0.0004282782319933176
# krfgwkdenc-algo-1-hfrjq | step 993, loss = 0.00024689140263944864
# krfgwkdenc-algo-1-hfrjq | step 994, loss = 0.0002887814771384001
# krfgwkdenc-algo-1-hfrjq | step 995, loss = 0.00027869659243151546
# krfgwkdenc-algo-1-hfrjq | step 996, loss = 0.00028760056011378765
# krfgwkdenc-algo-1-hfrjq | step 997, loss = 0.0004328765789978206
# krfgwkdenc-algo-1-hfrjq | step 998, loss = 0.00032794717117212713
# krfgwkdenc-algo-1-hfrjq | step 999, loss = 0.0002820704539772123
# krfgwkdenc-algo-1-hfrjq | Training complete.
# krfgwkdenc-algo-1-hfrjq exited with code 0
# Aborting on container exit...
# ===== Job Complete =====

# %%
predictor = estimator.deploy(1, instance_type)

# %%
predictor.delete_endpoint()

# %% [markdown]
# # Part 2: Training and Hosting your Algorithm in Amazon SageMaker
# Once you have your container packaged, you can use it to train and serve models. Let's do that with the algorithm we made above.
#
# ## Set up the environment
# Here we specify the bucket to use and the role that is used for working with SageMaker.

# %%
# S3 prefix
prefix = 'DEMO-jittor'

# %% [markdown]
# ## Create the session
#
# The session remembers our connection parameters to SageMaker. We use it to perform all of our SageMaker operations.

# %%
import sagemaker as sage

sess = sage.Session()

# %% [markdown]
# ## Upload the data for training
#
# We will use the tools provided by the SageMaker Python SDK to upload the data to a default bucket.

# %%
WORK_DIRECTORY = '/home/ec2-user/SageMaker/jittor_sagemaker'
data_location = sess.upload_data(WORK_DIRECTORY, key_prefix=prefix)
print(data_location)

# %% [markdown]
# ## Training on SageMaker
# Training a model on SageMaker with the Python SDK is done in a way that is similar to the way we trained it locally. This is done by changing our train_instance_type from `local` to one of our [supported EC2 instance types](https://aws.amazon.com/sagemaker/pricing/instance-types/).
#
# In addition, we must now specify the ECR image URL, which we just pushed above.
#
# Finally, our local training dataset has to be in Amazon S3 and the S3 URL to our dataset is passed into the `fit()` call.
#
# Let's first fetch our ECR image url that corresponds to the image we just built and pushed.

# %%
import boto3

client = boto3.client('sts')
account = client.get_caller_identity()['Account']

my_session = boto3.session.Session()
region = my_session.region_name

algorithm_name = 'jittor'

if region.startswith('cn'):
    ecr_image = '{}.dkr.ecr.{}.amazonaws.com.cn/{}:latest'.format(account, region, algorithm_name)
else:
    ecr_image = '{}.dkr.ecr.{}.amazonaws.com/{}:latest'.format(account, region, algorithm_name)

print(ecr_image)

# %%
from sagemaker.estimator import Estimator

instance_type = 'ml.p3.2xlarge'

estimator = Estimator(role=role,
                      instance_count=1,
                      instance_type=instance_type,
                      image_uri=ecr_image,
                      hyperparameters=hyperparameters)

estimator.fit({'training': data_location})

# %%
instance_type = 'ml.m5.xlarge'
predictor = estimator.deploy(1, instance_type)

# %% [markdown]
# ## Optional cleanup
# When you're done with the endpoint, you should clean it up.
#
# All of the training jobs, models and endpoints we created can be viewed through the SageMaker console of your AWS account.

# %%
predictor.delete_endpoint()

# %% [markdown]
# # Reference
# - [How Amazon SageMaker interacts with your Docker container for training](https://docs.aws.amazon.com/sagemaker/latest/dg/your-algorithms-training-algo.html)
# - [How Amazon SageMaker interacts with your Docker container for inference](https://docs.aws.amazon.com/sagemaker/latest/dg/your-algorithms-inference-code.html)
# - [CIFAR-10 Dataset](https://www.cs.toronto.edu/~kriz/cifar.html)
# - [SageMaker Python SDK](https://github.com/aws/sagemaker-python-sdk)
# - [Dockerfile](https://docs.docker.com/engine/reference/builder/)
# - [scikit-bring-your-own](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/advanced_functionality/scikit_bring_your_own/scikit_bring_your_own.ipynb)
